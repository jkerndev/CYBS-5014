# %% [markdown]
# # Lab3: Memory Analysis Lab Deeper Dive
#
# Identifying memory archive with suspicious process with additional detail. Notebook run on a [WIN-FOR](https://github.com/digitalsleuth/WIN-FOR) configured machine.

# %%
import os
import re
import time
import math

print(f"Jupyter Lab running in directory {os.getcwd()}")
# Out:
# Jupyter Lab running in directory C:\Users\vboxuser\repos\CYBS-5014\lab3

# %%
# Setup

IMG = Path(r"..\iveep\CTICOE-iveep_374_2025-03-17T17-27Z.mem")
CASE_DIR  = Path.cwd() / "output"
VOL = Path(r"C:\Users\vboxuser\repos\volatility3\vol.py")
VOL2 = Path(r"C:\Users\vboxuser\repos\volatility\vol.py")

CREATE_NO_WINDOW = 0x08000000
si = subprocess.STARTUPINFO()
if hasattr(subprocess, "STARTF_USESHOWWINDOW"):
    si.dwFlags |= subprocess.STARTF_USESHOWWINDOW

# %% [markdown]
# # Volatility Wrapper Functions

# %%
from pathlib import Path
import subprocess, hashlib, json, textwrap, os, sys, shlex
import pefile

def vol(plugin, *args):
    cmd = [sys.executable, str(VOL), "-f", str(IMG), str(plugin)] + [str(a) for a in args]
    p = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    out, err = p.communicate()
    if p.returncode != 0:
        sys.stderr.write(err)
    return out

def vol2(plugin, *args):
    cmd = [sys.executable, str(VOL2), "-f", str(IMG), str(plugin)] + [str(a) for a in args]
    p = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    out, err = p.communicate()
    if p.returncode != 0:
        sys.stderr.write(err)
    return out

def run_cmd(cmd, live=True, timeout=None):
    print(f"$ {cmd}")
    p = subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    out, err = p.communicate(timeout=timeout)
    sout, serr = out.decode(errors="ignore"), err.decode(errors="ignore")
    if live:
        if sout: print(sout)
        if serr: print(serr, file=sys.stderr)
    return p.returncode, sout, serr

def run_headless(argv, timeout=None):
    """Return (rc, stdout, stderr) for external tool calls, headless."""
    p = subprocess.run(
        argv,
        stdout=subprocess.PIPE,
        stderr=subprocess.PIPE,
        shell=False,
        creationflags=CREATE_NO_WINDOW,
        startupinfo=si,
        timeout=timeout,
    )
    so = p.stdout.decode(errors="ignore")
    se = p.stderr.decode(errors="ignore")
    return p.returncode, so, se

def tool_exists(path): 
    return Path(path).exists() if path else False

def save(txt, name):
    out_path = os.path.join(str(CASE_DIR), str(name))
    if not os.path.isdir(str(CASE_DIR)):
        try:
            os.makedirs(str(CASE_DIR))
        except OSError:
            pass  # already exists
    with open(out_path, 'wb') as f:
        f.write(txt)
    return out_path

from __future__ import print_function

def printvol(txt):
    return print(txt.decode('utf-8'))

def sha256(p):
    h = hashlib.sha256()
    with open(p, "rb") as f:
        for chunk in iter(lambda: f.read(1<<20), b""):
            h.update(chunk)
    return h.hexdigest()

def ascii_strings(blob, minlen=6):
    out = []
    cur = []
    for b in blob:
        if 32 <= b <= 126:
            cur.append(b)
        else:
            if len(cur) >= minlen:
                out.append(bytes(cur).decode(errors="ignore"))
            cur = []
    if len(cur) >= minlen:
        out.append(bytes(cur).decode(errors="ignore"))
    return out

def entropy(data: bytes) -> float:
    if not data: return 0.0
    from math import log2
    freq = [0]*256
    for b in data: freq[b]+=1
    probs = [f/len(data) for f in freq if f]
    return -sum(p*math.log2(p) for p in probs)

# %% [markdown]
# ## Overview from lab2
#
# - System time in image: **2025‑03‑17 17:27:09 UTC**
# - Kernel: Windows 10 (x64), kernel family **19041**, 4 logical CPUs
# - Prior triage suspects (from Labs 1–2):
#   - `PSEXESVC.exe` (PID 11296) -> `excel-update.exe` (PID 4672) -> `cmd.exe` (PID 13752) -> `powershell.exe` (PID 13156)
#   - **Rogue `spoolsv.exe` (PID 14536)** spawned by interactive PowerShell (Session 2)
#   - `ScreenConnect.*` service/client processes (PIDs 6988, 14756, 1772)
#
# **New Lab 3 goal:** choose one additional suspicious process and deep‑dive it: the **rogue `spoolsv.exe` (PID 14536)** and/or `ScreenConnect` service (PID 6988). since we already looked at the excel-update.exe chain primarily in the last lab.
#
# For this notebook, I will focus on `spoolsv.exe`

# %% [markdown]
# # Deep dive into `spoolsv.exe` (PID 14536)

# %%
# Identity, command line, genealogy 
# !python "{VOL}" -f "{IMG}" windows.pslist --pid 14536
# !python "{VOL}" -f "{IMG}" windows.cmdline --pid 14536
# !python "{VOL}" -f "{IMG}" windows.pstree | findstr /i 14536
# Out:
# Volatility 3 Framework 2.26.2
#
# PID	PPID	ImageFileName	Offset(V)	Threads	Handles	SessionId	Wow64	CreateTime	ExitTime	File output
#
# 14536	15172	spoolsv.exe	0x840e91a11080	9	-	2	False	2025-03-17 17:12:10.000000 UTC	N/A	Disabled
# Progress:    0.00		Scanning Elf64Layer using PageMapScanner
#
# Progress:    0.00		Scanning Elf64Layer using PageMapScanner
#
# Progress:   23.33		Scanning Elf64Layer using PageMapScanner
#
# Progress:    0.00		Scanning Elf64Layer using PageMapScanner
#
# Progress:  100.00		Stacking attempts finished
#
# Progress:    0.00		Scanning layer_name using PdbSignatureScanner
#
# Progress:    0.00		Scanning layer_name using PdbSignatureScanner
#
# Progress:  100.00		PDB scanning finished
# Volatility 3 Framework 2.26.2
#
# PID	Process	Args
#
# 14536	spoolsv.exe	C:\Windows\System32\spoolsv.exe
# Progress:    0.00		Scanning Elf64Layer using PageMapScanner
#
# Progress:    0.00		Scanning Elf64Layer using PageMapScanner
#
# Progress:   23.33		Scanning Elf64Layer using PageMapScanner
#
# Progress:    0.00		Scanning Elf64Layer using PageMapScanner
#
# Progress:  100.00		Stacking attempts finished
#
# Progress:    0.00		Scanning layer_name using PdbSignatureScanner
#
# Progress:    0.00		Scanning layer_name using PdbSignatureScanner
#
# Progress:  100.00		PDB scanning finished
# **** 14536	15172	spoolsv.exe	0x840e91a11080	9	-	2	False	2025-03-17 17:12:10.000000 UTC	N/A	\Device\HarddiskVolume3\Windows\System32\spoolsv.exe	C:\Windows\System32\spoolsv.exe	C:\Windows\System32\spoolsv.exe
# Progress:    0.00		Scanning Elf64Layer using PageMapScanner
#
# Progress:    0.00		Scanning Elf64Layer using PageMapScanner
#
# Progress:   23.33		Scanning Elf64Layer using PageMapScanner
#
# Progress:    0.00		Scanning Elf64Layer using PageMapScanner
#
# Progress:  100.00		Stacking attempts finished
#
# Progress:    0.00		Scanning layer_name using PdbSignatureScanner
#
# Progress:    0.00		Scanning layer_name using PdbSignatureScanner
#
# Progress:  100.00		PDB scanning finished

# %% [markdown]
# # Analysis
#
# ## Identity & Genealogy
#
# - Parent: `powershell.exe` (PID 15172) in Session 2 (interactive)
# - Create time: 2025-03-17 17:12:10 UTC
# - Path/args: `C:\Windows\System32\spoolsv.exe`, no arguments
#
# ## Notes
#
# The real print spooler service should run as a service under session 0 under the service control tree, not as a child of interactive PowerShell / Session 2. Additionally, the timing aligns with the ealier PsExec/excel-update.exe activity window. This is likely a spoolsv look-alike spawned for post-exploit activity.

# %%
# Modules & memory regions
# !python "{VOL}" -f "{IMG}" windows.dlllist --pid 14536
# !python "{VOL}" -f "{IMG}" windows.vadinfo --pid 14536
# !python "{VOL}" -f "{IMG}" windows.malfind --pid 14536
# Out:
# Volatility 3 Framework 2.26.2
#
# PID	Process	Base	Size	Name	Path	LoadTime	File output
#
# 14536	spoolsv.exe	0x7ff7eb690000	0xd2000	spoolsv.exe	C:\Windows\System32\spoolsv.exe	2025-03-17 17:12:10.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb50170000	0x1f8000	ntdll.dll	C:\Windows\SYSTEM32\ntdll.dll	2025-03-17 17:12:10.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb4fac0000	0xbd000	KERNEL32.DLL	C:\Windows\System32\KERNEL32.DLL	2025-03-17 17:12:10.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb4dd20000	0x2f6000	KERNELBASE.dll	C:\Windows\System32\KERNELBASE.dll	2025-03-17 17:12:10.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb4f180000	0x19f000	USER32.dll	C:\Windows\System32\USER32.dll	2025-03-17 17:12:10.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb4d990000	0x22000	win32u.dll	C:\Windows\System32\win32u.dll	2025-03-17 17:12:10.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb4e570000	0x2b000	GDI32.dll	C:\Windows\System32\GDI32.dll	2025-03-17 17:12:10.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb4daa0000	0x117000	gdi32full.dll	C:\Windows\System32\gdi32full.dll	2025-03-17 17:12:10.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb4d8f0000	0x9d000	msvcp_win.dll	C:\Windows\System32\msvcp_win.dll	2025-03-17 17:12:10.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb4e020000	0x100000	ucrtbase.dll	C:\Windows\System32\ucrtbase.dll	2025-03-17 17:12:10.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb4e1b0000	0x9e000	msvcrt.dll	C:\Windows\System32\msvcrt.dll	2025-03-17 17:12:10.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb50090000	0xa0000	sechost.dll	C:\Windows\System32\sechost.dll	2025-03-17 17:12:10.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb4f050000	0x123000	RPCRT4.dll	C:\Windows\System32\RPCRT4.dll	2025-03-17 17:12:10.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb4da70000	0x27000	bcrypt.dll	C:\Windows\System32\bcrypt.dll	2025-03-17 17:12:10.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb4cc00000	0xca000	DNSAPI.dll	C:\Windows\System32\DNSAPI.dll	2025-03-17 17:12:10.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb49060000	0xa000	DSROLE.dll	C:\Windows\System32\DSROLE.dll	2025-03-17 17:12:10.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb4e450000	0xb0000	advapi32.dll	C:\Windows\System32\advapi32.dll	2025-03-17 17:12:10.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb4ee20000	0x2f000	IMM32.DLL	C:\Windows\System32\IMM32.DLL	2025-03-17 17:12:10.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb4cbc0000	0x3b000	IPHLPAPI.DLL	C:\Windows\SYSTEM32\IPHLPAPI.DLL	2025-03-17 17:12:10.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb4edb0000	0x8000	NSI.dll	C:\Windows\System32\NSI.dll	2025-03-17 17:12:10.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb4c780000	0x10a000	winhttp.DLL	C:\Windows\System32\winhttp.DLL	2025-03-17 17:12:10.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb4e500000	0x6b000	WS2_32.dll	C:\Windows\System32\WS2_32.dll	2025-03-17 17:12:10.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb4fd30000	0x353000	combase.dll	C:\Windows\System32\combase.dll	2025-03-17 17:12:10.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb46d10000	0x17000	dhcpcsvc6.DLL	C:\Windows\SYSTEM32\dhcpcsvc6.DLL	2025-03-17 17:12:10.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb4e120000	0x82000	bcryptPrimitives.dll	C:\Windows\System32\bcryptPrimitives.dll	2025-03-17 17:12:10.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb46cf0000	0x1d000	dhcpcsvc.DLL	C:\Windows\SYSTEM32\dhcpcsvc.DLL	2025-03-17 17:12:10.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb44dc0000	0x98000	webio.dll	C:\Windows\System32\webio.dll	2025-03-17 17:12:10.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb4cee0000	0x6a000	mswsock.dll	C:\Windows\system32\mswsock.dll	2025-03-17 17:12:10.000000 UTC	Disabled
# 14536	spoolsv.exe	0x29b0000	0x16000	umppc19205.dll	C:\Windows\System32\umppc19205.dll	2025-03-17 17:12:10.000000 UTC	Disabled
# 14536	spoolsv.exe	0x2e50000	0x13000	CsXumd64_19205.dll	C:\Windows\System32\CsXumd64_19205.dll	2025-03-17 17:12:10.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb47960000	0xb000	WINNSI.DLL	C:\Windows\SYSTEM32\WINNSI.DLL	2025-03-17 17:12:10.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb4d700000	0x32000	SspiCli.dll	C:\Windows\System32\SspiCli.dll	2025-03-17 17:12:10.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb4e2c0000	0x12b000	ole32.DLL	C:\Windows\System32\ole32.DLL	2025-03-17 17:12:10.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb4ef80000	0xcd000	oleaut32.DLL	C:\Windows\System32\oleaut32.DLL	2025-03-17 17:12:10.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb3e920000	0x4d6000	wininet.DLL	C:\Windows\System32\wininet.DLL	2025-03-17 17:12:11.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb26ef0000	0x65000	mscoree.DLL	C:\Windows\System32\mscoree.DLL	2025-03-17 17:12:11.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb4e5a0000	0x76a000	shell32.DLL	C:\Windows\System32\shell32.DLL	2025-03-17 17:12:11.000000 UTC	Disabled
# 14536	spoolsv.exe	0x2fe0000	0x36000	ScriptControl64_19205.dll	C:\Windows\System32\ScriptControl64_19205.dll	2025-03-17 17:12:11.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb41200000	0xa000	VERSION.dll	C:\Windows\SYSTEM32\VERSION.dll	2025-03-17 17:12:11.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb3d080000	0x1f000	amsi.DLL	C:\Windows\System32\amsi.DLL	2025-03-17 17:12:11.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb4d180000	0x2e000	wldp.DLL	C:\Windows\System32\wldp.DLL	2025-03-17 17:12:11.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb4d0f0000	0xc000	CRYPTBASE.DLL	C:\Windows\System32\CRYPTBASE.DLL	2025-03-17 17:12:11.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb338c0000	0x27000	winmm.dll	C:\Windows\SYSTEM32\winmm.dll	2025-03-17 17:12:11.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb4d680000	0x4b000	powrprof.dll	C:\Windows\SYSTEM32\powrprof.dll	2025-03-17 17:12:11.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb4d660000	0x12000	UMPDC.dll	C:\Windows\SYSTEM32\UMPDC.dll	2025-03-17 17:12:11.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb4d6d0000	0x2e000	userenv.dll	C:\Windows\SYSTEM32\userenv.dll	2025-03-17 17:12:13.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb4d760000	0x24000	profapi.dll	C:\Windows\SYSTEM32\profapi.dll	2025-03-17 17:12:13.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb3f290000	0x19000	netapi32.dll	C:\Windows\SYSTEM32\netapi32.dll	2025-03-17 17:12:13.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb4c920000	0x19000	WKSCLI.DLL	C:\Windows\SYSTEM32\WKSCLI.DLL	2025-03-17 17:12:13.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb4ccd0000	0xc000	NETUTILS.DLL	C:\Windows\SYSTEM32\NETUTILS.DLL	2025-03-17 17:12:13.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb3e770000	0x19000	SAMCLI.DLL	C:\Windows\SYSTEM32\SAMCLI.DLL	2025-03-17 17:12:13.000000 UTC	Disabled
# 14536	spoolsv.exe	0x7ffb459d0000	0x27000	SAMLIB.dll	C:\Windows\SYSTEM32\SAMLIB.dll	2025-03-17 17:12:13.000000 UTC	Disabled
# Progress:    0.00		Scanning Elf64Layer using PageMapScanner
#
# Progress:    0.00		Scanning Elf64Layer using PageMapScanner
#
# Progress:   23.33		Scanning Elf64Layer using PageMapScanner
#
# Progress:    0.00		Scanning Elf64Layer using PageMapScanner
#
# Progress:  100.00		Stacking attempts finished
#
# Progress:    0.00		Scanning layer_name using PdbSignatureScanner
#
# Progress:    0.00		Scanning layer_name using PdbSignatureScanner
#
# Progress:  100.00		PDB scanning finished
# Volatility 3 Framework 2.26.2
#
# PID	Process	Offset	Start VPN	End VPN	Tag	Protection	CommitCharge	PrivateMemory	Parent	File	File output
#
# 14536	spoolsv.exe	0xffff840ea808ed80	0x7ffee000	0x7ffeefff	VadS	PAGE_READONLY	1	1	0x0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840eab4a9da0	0x3020000	0x302ffff	VadS	PAGE_READWRITE	15	1	0xffff840ea808ed80	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9e7c9080	0x2840000	0x2840fff	Vad 	PAGE_READONLY	0	0	0xffff840eab4a9da0	\Windows\System32\en-US\spoolsv.exe.mui	Disabled
# 14536	spoolsv.exe	0xffff840eab4a9350	0xb70000	0xb70fff	VadS	PAGE_EXECUTE_READWRITE	1	1	0xffff840e9e7c9080	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea808e740	0xa40000	0xb3ffff	VadS	PAGE_READWRITE	15	1	0xffff840eab4a9350	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e98d44b60	0xa00000	0xa0ffff	Vad 	PAGE_READWRITE	0	0	0xffff840ea808e740	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea808edd0	0x800000	0x9fffff	VadS	PAGE_READWRITE	19	1	0xffff840e98d44b60	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9cfb31a0	0xa20000	0xa3cfff	Vad 	PAGE_READONLY	0	0	0xffff840e98d44b60	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e97866e90	0xa10000	0xa10fff	Vad 	PAGE_READONLY	0	0	0xffff840e9cfb31a0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9cfac4e0	0xb50000	0xb50fff	Vad 	PAGE_READONLY	0	0	0xffff840ea808e740	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9cfa9100	0xb40000	0xb43fff	Vad 	PAGE_READONLY	0	0	0xffff840e9cfac4e0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840eab4a9210	0xb60000	0xb61fff	VadS	PAGE_READWRITE	2	1	0xffff840e9cfac4e0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e98d46640	0xcd0000	0xd98fff	Vad 	PAGE_READONLY	0	0	0xffff840eab4a9350	\Windows\System32\locale.nls	Disabled
# 14536	spoolsv.exe	0xffff840e97869d70	0xba0000	0xba0fff	Vad 	PAGE_READONLY	0	0	0xffff840e98d46640	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea4b0e800	0xb80000	0xb99fff	VadS	PAGE_READWRITE	2	1	0xffff840e97869d70	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9786b5d0	0xbc0000	0xbc7fff	Vad 	PAGE_READONLY	0	0	0xffff840e97869d70	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9786ad10	0xbb0000	0xbb0fff	Vad 	PAGE_READONLY	0	0	0xffff840e9786b5d0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea4b0e0d0	0xbd0000	0xccffff	VadS	PAGE_READWRITE	150	1	0xffff840e9786b5d0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea3f678d0	0x1030000	0x1041fff	VadS	PAGE_READWRITE	18	1	0xffff840e98d46640	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea3f627e0	0xdf0000	0xe2ffff	VadS	PAGE_READWRITE	64	1	0xffff840ea3f678d0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea3f62560	0xde0000	0xdeffff	VadS	PAGE_READWRITE	16	1	0xffff840ea3f627e0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea3f62650	0xda0000	0xddffff	VadS	PAGE_READWRITE	64	1	0xffff840ea3f62560	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea70d0d10	0xe30000	0xf2ffff	VadS	PAGE_READWRITE	15	1	0xffff840ea3f627e0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9dcec2f0	0xf30000	0x102ffff	VadS	PAGE_READWRITE	15	1	0xffff840ea70d0d10	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9786b210	0x10a0000	0x129ffff	Vad 	PAGE_READONLY	0	0	0xffff840ea3f678d0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea4abf380	0x1050000	0x1061fff	VadS	PAGE_READWRITE	18	1	0xffff840e9786b210	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d3460	0x1070000	0x1081fff	VadS	PAGE_READWRITE	18	1	0xffff840ea4abf380	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9e7c7280	0x12a0000	0x1420fff	Vad 	PAGE_READONLY	0	0	0xffff840e9786b210	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9e7c78c0	0x1430000	0x2830fff	Vad 	PAGE_READONLY	0	0	0xffff840e9e7c7280	N/A	Disabled
# 14536	spoolsv.exe	0xffff840eab4a9260	0x29f0000	0x29fffff	VadS	PAGE_READWRITE	8	1	0xffff840e9e7c9080	N/A	Disabled
# 14536	spoolsv.exe	0xffff840eab4a9990	0x2990000	0x2990fff	VadS	PAGE_READWRITE	1	1	0xffff840eab4a9260	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d4a40	0x28f0000	0x2901fff	VadS	PAGE_READWRITE	18	1	0xffff840eab4a9990	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d3d20	0x2890000	0x28a1fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d4a40	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d35f0	0x2870000	0x2881fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d3d20	N/A	Disabled
# 14536	spoolsv.exe	0xffff840eab4a9440	0x2850000	0x2869fff	VadS	PAGE_READWRITE	1	1	0xffff840e9a5d35f0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d49a0	0x28d0000	0x28e1fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d3d20	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d3cd0	0x28b0000	0x28c1fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d49a0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9e7c8720	0x2970000	0x2974fff	Vad 	PAGE_READONLY	0	0	0xffff840e9a5d4a40	\Windows\System32\winnlsres.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d44a0	0x2930000	0x2941fff	VadS	PAGE_READWRITE	18	1	0xffff840e9e7c8720	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d4b80	0x2910000	0x2921fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d44a0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d4b30	0x2950000	0x2961fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d44a0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9e7c84a0	0x2980000	0x298ffff	Vad 	PAGE_READONLY	0	0	0xffff840e9e7c8720	\Windows\System32\en-US\winnlsres.dll.mui	Disabled
# 14536	spoolsv.exe	0xffff840ea0302760	0x29b0000	0x29c5fff	VadI	PAGE_EXECUTE_WRITECOPY	9	0	0xffff840eab4a9990	\Windows\System32\umppc19205.dll	Disabled
# 14536	spoolsv.exe	0xffff840eab4a9030	0x29a0000	0x29a1fff	VadS	PAGE_READWRITE	2	1	0xffff840ea0302760	N/A	Disabled
# 14536	spoolsv.exe	0xffff840eab4a93a0	0x29d0000	0x29dffff	VadS	PAGE_READWRITE	2	1	0xffff840ea0302760	N/A	Disabled
# 14536	spoolsv.exe	0xffff840eab4a9530	0x29e0000	0x29e0fff	VadS	PAGE_READWRITE	1	1	0xffff840eab4a93a0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840eab4a9ee0	0x2e70000	0x2e75fff	VadS	PAGE_READWRITE	6	1	0xffff840eab4a9260	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d49f0	0x2aa0000	0x2ab1fff	VadS	PAGE_READWRITE	18	1	0xffff840eab4a9ee0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d4450	0x2a60000	0x2a71fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d49f0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d44f0	0x2a20000	0x2a31fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d4450	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d42c0	0x2a00000	0x2a11fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d44f0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d4360	0x2a40000	0x2a51fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d44f0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d4900	0x2a80000	0x2a91fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d4450	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9e7c0ac0	0x2b00000	0x2e37fff	Vad 	PAGE_READONLY	0	0	0xffff840e9a5d49f0	\Windows\Globalization\Sorting\SortDefault.nls	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d4bd0	0x2ac0000	0x2ad1fff	VadS	PAGE_READWRITE	18	1	0xffff840e9e7c0ac0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d4770	0x2ae0000	0x2af1fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d4bd0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840eab4a9710	0x2e40000	0x2e41fff	VadS	PAGE_READWRITE	2	1	0xffff840e9e7c0ac0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea0303960	0x2e50000	0x2e62fff	VadI	PAGE_EXECUTE_WRITECOPY	8	0	0xffff840eab4a9710	\Windows\System32\CsXumd64_19205.dll	Disabled
# 14536	spoolsv.exe	0xffff840eab4aa3e0	0x2fa0000	0x2fa0fff	VadS	PAGE_READWRITE	1	1	0xffff840eab4a9ee0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9e7c8900	0x2f80000	0x2f80fff	Vad 	PAGE_READONLY	0	0	0xffff840eab4aa3e0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840eab4a9f80	0x2e80000	0x2f7ffff	VadS	PAGE_READWRITE	2	1	0xffff840e9e7c8900	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9786b670	0x2f90000	0x2f92fff	Vad 	PAGE_READONLY	0	0	0xffff840e9e7c8900	\Windows\System32\en-US\mswsock.dll.mui	Disabled
# 14536	spoolsv.exe	0xffff840eab4ab240	0x2fc0000	0x2fd9fff	VadS	PAGE_READWRITE	1	1	0xffff840eab4aa3e0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840eab4aa840	0x2fb0000	0x2fb1fff	VadS	PAGE_READWRITE	2	1	0xffff840eab4ab240	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e92f15180	0x2fe0000	0x3015fff	VadI	PAGE_EXECUTE_WRITECOPY	14	0	0xffff840eab4ab240	\Windows\System32\ScriptControl64_19205.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d5490	0x2ace0000	0x2acf1fff	VadS	PAGE_READWRITE	18	1	0xffff840eab4a9da0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea4b169b0	0x2a7a0000	0x2a7dffff	VadS	PAGE_READWRITE	64	1	0xffff840e9a5d5490	N/A	Disabled
# 14536	spoolsv.exe	0xffff840eab4ab6a0	0x3e00000	0x48e5fff	VadS	PAGE_EXECUTE_READWRITE	2790	1	0xffff840ea4b169b0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840eab4ab2e0	0x3c20000	0x3c2ffff	VadS	PAGE_READWRITE	7	1	0xffff840eab4ab6a0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840eab4aad90	0x3040000	0x3abafff	VadS	PAGE_READWRITE	2683	1	0xffff840eab4ab2e0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840eab4a92b0	0x3030000	0x303ffff	VadS	PAGE_READWRITE	2	1	0xffff840eab4aad90	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9f686900	0x3bc0000	0x3bfffff	VadS	PAGE_READWRITE	64	1	0xffff840eab4aad90	N/A	Disabled
# 14536	spoolsv.exe	0xffff840eab4aaed0	0x3ac0000	0x3bbffff	VadS	PAGE_READWRITE	15	1	0xffff840e9f686900	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9f687030	0x3c00000	0x3c1ffff	VadS	PAGE_READWRITE	32	1	0xffff840e9f686900	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9f68b860	0x3d60000	0x3d6ffff	VadS	PAGE_READWRITE	16	1	0xffff840eab4ab2e0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9f68a050	0x3d30000	0x3d41fff	VadS	PAGE_READWRITE	18	1	0xffff840e9f68b860	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9f6871c0	0x3c30000	0x3d2ffff	VadS	PAGE_READWRITE	1	1	0xffff840e9f68a050	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9f68bdb0	0x3d50000	0x3d5ffff	VadS	PAGE_READWRITE	16	1	0xffff840e9f68a050	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea4b0ffc0	0x3db0000	0x3deffff	VadS	PAGE_READWRITE	64	1	0xffff840e9f68b860	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea4b10420	0x3d70000	0x3daffff	VadS	PAGE_READWRITE	64	1	0xffff840ea4b0ffc0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea4b0fc50	0x3df0000	0x3dfffff	VadS	PAGE_READWRITE	2	1	0xffff840ea4b0ffc0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9f68c7b0	0x2a2f0000	0x2a3effff	VadS	PAGE_READWRITE	15	1	0xffff840eab4ab6a0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9f6896a0	0x290f0000	0x298effff	VadS	PAGE_READWRITE	1031	1	0xffff840e9f68c7b0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9f6876c0	0x50f0000	0x90effff	VadS	PAGE_READWRITE	1	1	0xffff840e9f6896a0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9f6872b0	0x48f0000	0x50effff	VadS	PAGE_READWRITE	1	1	0xffff840e9f6876c0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9f6880c0	0x90f0000	0x290effff	VadS	PAGE_READWRITE	1	1	0xffff840e9f6876c0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9f68aaa0	0x2a0f0000	0x2a1effff	VadS	PAGE_READWRITE	256	1	0xffff840e9f6896a0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9f68a140	0x298f0000	0x2a0effff	VadS	PAGE_READWRITE	2048	1	0xffff840e9f68aaa0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9f68be00	0x2a1f0000	0x2a2effff	VadS	PAGE_READWRITE	15	1	0xffff840e9f68aaa0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea4b0fe30	0x2a6f0000	0x2a701fff	VadS	PAGE_READWRITE	18	1	0xffff840e9f68c7b0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea4b106f0	0x2a4f0000	0x2a5effff	VadS	PAGE_READWRITE	15	1	0xffff840ea4b0fe30	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9f68c800	0x2a3f0000	0x2a4effff	VadS	PAGE_READWRITE	15	1	0xffff840ea4b106f0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9f68c990	0x2a5f0000	0x2a6effff	VadS	PAGE_READWRITE	15	1	0xffff840ea4b106f0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea4b15ab0	0x2a720000	0x2a75ffff	VadS	PAGE_READWRITE	64	1	0xffff840ea4b0fe30	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea4b15470	0x2a710000	0x2a71ffff	VadS	PAGE_READWRITE	16	1	0xffff840ea4b15ab0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea4b15b00	0x2a760000	0x2a79ffff	VadS	PAGE_READWRITE	64	1	0xffff840ea4b15ab0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d4ef0	0x2aae0000	0x2aaf1fff	VadS	PAGE_READWRITE	18	1	0xffff840ea4b169b0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d4220	0x2a9e0000	0x2a9f1fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d4ef0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d4270	0x2a960000	0x2a971fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d4220	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d47c0	0x2a920000	0x2a931fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d4270	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9f08a5c0	0x2a7e0000	0x2a91ffff	Vad 	PAGE_READONLY	0	0	0xffff840e9a5d47c0	\Windows\System32\en-US\KernelBase.dll.mui	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d4860	0x2a940000	0x2a951fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d47c0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d4a90	0x2a9a0000	0x2a9b1fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d4270	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d4540	0x2a980000	0x2a991fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d4a90	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d4950	0x2a9c0000	0x2a9d1fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d4a90	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d4630	0x2aa60000	0x2aa71fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d4220	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d4ae0	0x2aa20000	0x2aa31fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d4630	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d4590	0x2aa00000	0x2aa11fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d4ae0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d43b0	0x2aa40000	0x2aa51fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d4ae0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d46d0	0x2aaa0000	0x2aab1fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d4630	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d4400	0x2aa80000	0x2aa91fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d46d0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d4d10	0x2aac0000	0x2aad1fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d46d0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d5440	0x2abe0000	0x2abf1fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d4ef0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d4f90	0x2ab60000	0x2ab71fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d5440	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d51c0	0x2ab20000	0x2ab31fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d4f90	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d4c20	0x2ab00000	0x2ab11fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d51c0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d4f40	0x2ab40000	0x2ab51fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d51c0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d4db0	0x2aba0000	0x2abb1fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d4f90	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d5120	0x2ab80000	0x2ab91fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d4db0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d53a0	0x2abc0000	0x2abd1fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d4db0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d4cc0	0x2ac60000	0x2ac71fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d5440	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d4ea0	0x2ac20000	0x2ac31fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d4cc0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d5580	0x2ac00000	0x2ac11fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d4ea0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d5530	0x2ac40000	0x2ac51fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d4ea0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d4d60	0x2aca0000	0x2acb1fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d4cc0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d5030	0x2ac80000	0x2ac91fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d4d60	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d4e50	0x2acc0000	0x2acd1fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d4d60	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea76a8270	0x2aee0000	0x2aef1fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d5490	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d5170	0x2ade0000	0x2adf1fff	VadS	PAGE_READWRITE	18	1	0xffff840ea76a8270	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d50d0	0x2ad60000	0x2ad71fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d5170	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d52b0	0x2ad20000	0x2ad31fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d50d0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d54e0	0x2ad00000	0x2ad11fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d52b0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d5260	0x2ad40000	0x2ad51fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d52b0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d55d0	0x2ada0000	0x2adb1fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d50d0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d5300	0x2ad80000	0x2ad91fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d55d0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d4c70	0x2adc0000	0x2add1fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d55d0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d53f0	0x2ae60000	0x2ae71fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d5170	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d5350	0x2ae20000	0x2ae31fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d53f0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d5210	0x2ae00000	0x2ae11fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d5350	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d4e00	0x2ae40000	0x2ae51fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d5350	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea76a8130	0x2aea0000	0x2aeb1fff	VadS	PAGE_READWRITE	18	1	0xffff840e9a5d53f0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d5620	0x2ae80000	0x2ae91fff	VadS	PAGE_READWRITE	18	1	0xffff840ea76a8130	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea76a8180	0x2aec0000	0x2aed1fff	VadS	PAGE_READWRITE	18	1	0xffff840ea76a8130	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea76a8540	0x2afe0000	0x2aff1fff	VadS	PAGE_READWRITE	18	1	0xffff840ea76a8270	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea76a84a0	0x2af60000	0x2af71fff	VadS	PAGE_READWRITE	18	1	0xffff840ea76a8540	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea76a7eb0	0x2af20000	0x2af31fff	VadS	PAGE_READWRITE	18	1	0xffff840ea76a84a0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea76a7c30	0x2af00000	0x2af11fff	VadS	PAGE_READWRITE	18	1	0xffff840ea76a7eb0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea76a8450	0x2af40000	0x2af51fff	VadS	PAGE_READWRITE	18	1	0xffff840ea76a7eb0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea76a7be0	0x2afa0000	0x2afb1fff	VadS	PAGE_READWRITE	18	1	0xffff840ea76a84a0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea76a84f0	0x2af80000	0x2af91fff	VadS	PAGE_READWRITE	18	1	0xffff840ea76a7be0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea76a7f00	0x2afc0000	0x2afd1fff	VadS	PAGE_READWRITE	18	1	0xffff840ea76a7be0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea76a7e10	0x2b060000	0x2b071fff	VadS	PAGE_READWRITE	18	1	0xffff840ea76a8540	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea76a8090	0x2b020000	0x2b031fff	VadS	PAGE_READWRITE	18	1	0xffff840ea76a7e10	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea76a7cd0	0x2b000000	0x2b011fff	VadS	PAGE_READWRITE	18	1	0xffff840ea76a8090	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea76a7d20	0x2b040000	0x2b051fff	VadS	PAGE_READWRITE	18	1	0xffff840ea76a8090	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea76ab330	0x2b0a0000	0x2b0b1fff	VadS	PAGE_READWRITE	18	1	0xffff840ea76a7e10	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea76a7e60	0x2b080000	0x2b091fff	VadS	PAGE_READWRITE	18	1	0xffff840ea76ab330	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea808e7e0	0x7ffe0000	0x7ffe0fff	VadS	PAGE_READONLY	1	1	0xffff840ea76ab330	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea76ab740	0x2b0c0000	0x2b0d1fff	VadS	PAGE_READWRITE	18	1	0xffff840ea808e7e0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9e7ca480	0x7ffb46cf0000	0x7ffb46d0cfff	Vad 	PAGE_EXECUTE_WRITECOPY	3	0	0xffff840ea808ed80	\Windows\System32\dhcpcsvc.dll	Disabled
# 14536	spoolsv.exe	0xffff840eab4aa390	0x7fface510000	0x7fface511fff	VadS	PAGE_EXECUTE_READWRITE	2	1	0xffff840e9e7ca480	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9cfb1620	0x7df50cdb0000	0x7ff50cdaffff	Vad 	PAGE_NOACCESS	15488	0	0xffff840eab4aa390	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5c57c0	0xc001000000	0xc0043fffff	VadS	PAGE_READWRITE	0	1	0xffff840e9cfb1620	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea3f669d0	0xc000800000	0xc000bfffff	VadS	PAGE_READWRITE	736	1	0xffff840e9a5c57c0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9f689e70	0xc000000000	0xc0003fffff	VadS	PAGE_READWRITE	766	1	0xffff840ea3f669d0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840eab4a9e40	0x7fff0000	0x170e38fff	VadS	PAGE_EXECUTE_READWRITE	986697	1	0xffff840e9f689e70	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea4b0fed0	0xc000400000	0xc0007fffff	VadS	PAGE_READWRITE	890	1	0xffff840e9f689e70	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea4abf290	0xc000c00000	0xc000ffffff	VadS	PAGE_READWRITE	0	1	0xffff840ea3f669d0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea4b0e620	0x7df40ad40000	0x7df50ad5ffff	VadS	PAGE_READWRITE	0	1	0xffff840e9a5c57c0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d4720	0xc008800000	0xc00cffffff	VadS	PAGE_READWRITE	0	1	0xffff840ea4b0e620	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d4680	0xc005000000	0xc0063fffff	VadS	PAGE_READWRITE	0	1	0xffff840e9a5d4720	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d4810	0xc004400000	0xc004ffffff	VadS	PAGE_READWRITE	0	1	0xffff840e9a5d4680	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d48b0	0xc006400000	0xc0087fffff	VadS	PAGE_READWRITE	0	1	0xffff840e9a5d4680	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea76a8040	0xc010400000	0xc014bfffff	VadS	PAGE_READWRITE	0	1	0xffff840e9a5d4720	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9a5d5080	0xc00d000000	0xc0103fffff	VadS	PAGE_READWRITE	0	1	0xffff840ea76a8040	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e98d46dc0	0x7df40ac40000	0x7df40ad3ffff	Vad 	PAGE_READONLY	0	0	0xffff840ea76a8040	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9cfb2ca0	0x7df50cd70000	0x7df50cd70fff	Vad 	PAGE_READONLY	0	0	0xffff840ea4b0e620	N/A	Disabled
# 14536	spoolsv.exe	0xffff840ea4b07780	0x7df50ad60000	0x7df50cd60fff	VadS	PAGE_READWRITE	1	1	0xffff840e9cfb2ca0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9cfb1e40	0x7df50cd80000	0x7df50cda2fff	Vad 	PAGE_READONLY	0	0	0xffff840e9cfb2ca0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840eab4aa020	0x7ffaccc00000	0x7ffaccc00fff	VadS	PAGE_EXECUTE_READWRITE	1	1	0xffff840e9cfb1620	N/A	Disabled
# 14536	spoolsv.exe	0xffff840eab4abd30	0x7ffabf2b0000	0x7ffabf2b0fff	VadS	PAGE_EXECUTE_READWRITE	1	1	0xffff840eab4aa020	N/A	Disabled
# 14536	spoolsv.exe	0xffff840eab4ab560	0x7ffaa6f60000	0x7ffaa6f60fff	VadS	PAGE_EXECUTE_READWRITE	1	1	0xffff840eab4abd30	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9cfb1260	0x7ff7eb690000	0x7ff7eb761fff	Vad 	PAGE_EXECUTE_WRITECOPY	5	0	0xffff840eab4ab560	\Windows\System32\spoolsv.exe	Disabled
# 14536	spoolsv.exe	0xffff840eab4abdd0	0x7ffabe790000	0x7ffabe790fff	VadS	PAGE_EXECUTE_READWRITE	1	1	0xffff840eab4ab560	N/A	Disabled
# 14536	spoolsv.exe	0xffff840eab4aa2a0	0x7ffacc890000	0x7ffacc890fff	VadS	PAGE_EXECUTE_READWRITE	1	1	0xffff840eab4abd30	N/A	Disabled
# 14536	spoolsv.exe	0xffff840eab4abd80	0x7ffacc940000	0x7ffacc940fff	VadS	PAGE_EXECUTE_READWRITE	1	1	0xffff840eab4aa2a0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840eab4a9bc0	0x7ffacd9c0000	0x7ffacd9c0fff	VadS	PAGE_EXECUTE_READWRITE	1	1	0xffff840eab4aa020	N/A	Disabled
# 14536	spoolsv.exe	0xffff840eab4a9cb0	0x7ffacd740000	0x7ffacd740fff	VadS	PAGE_EXECUTE_READWRITE	1	1	0xffff840eab4a9bc0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840eab4a9df0	0x7fface020000	0x7fface021fff	VadS	PAGE_EXECUTE_READWRITE	2	1	0xffff840eab4a9bc0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840eab4aa0c0	0x7ffad0370000	0x7ffad0370fff	VadS	PAGE_EXECUTE_READWRITE	1	1	0xffff840eab4aa390	N/A	Disabled
# 14536	spoolsv.exe	0xffff840eab4a9a30	0x7ffacf320000	0x7ffacf320fff	VadS	PAGE_EXECUTE_READWRITE	1	1	0xffff840eab4aa0c0	N/A	Disabled
# 14536	spoolsv.exe	0xffff840eab4a9b70	0x7ffacf180000	0x7ffacf180fff	VadS	PAGE_EXECUTE_READWRITE	1	1	0xffff840eab4a9a30	N/A	Disabled
# 14536	spoolsv.exe	0xffff840eab4aa250	0x7fface570000	0x7fface570fff	VadS	PAGE_EXECUTE_READWRITE	1	1	0xffff840eab4a9b70	N/A	Disabled
# 14536	spoolsv.exe	0xffff840eab4a9ad0	0x7ffacfb80000	0x7ffacfb80fff	VadS	PAGE_EXECUTE_READWRITE	1	1	0xffff840eab4a9a30	N/A	Disabled
# 14536	spoolsv.exe	0xffff840e9e7c8d60	0x7ffb3e920000	0x7ffb3edf5fff	Vad 	PAGE_EXECUTE_WRITECOPY	8	0	0xffff840eab4aa0c0	\Windows\System32\wininet.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9f606cc0	0x7ffb338c0000	0x7ffb338e6fff	Vad 	PAGE_EXECUTE_WRITECOPY	4	0	0xffff840e9e7c8d60	\Windows\System32\winmm.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9e7c8ea0	0x7ffb26ef0000	0x7ffb26f54fff	Vad 	PAGE_EXECUTE_WRITECOPY	10	0	0xffff840e9f606cc0	\Windows\System32\mscoree.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9e7c7f00	0x7ffb3d080000	0x7ffb3d09efff	Vad 	PAGE_EXECUTE_WRITECOPY	6	0	0xffff840e9f606cc0	\Windows\System32\amsi.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9aa983a0	0x7ffb3e770000	0x7ffb3e788fff	Vad 	PAGE_EXECUTE_WRITECOPY	7	0	0xffff840e9e7c7f00	\Windows\System32\samcli.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9e0c65c0	0x7ffb41200000	0x7ffb41209fff	Vad 	PAGE_EXECUTE_WRITECOPY	2	0	0xffff840e9e7c8d60	\Windows\System32\version.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9aa96500	0x7ffb3f290000	0x7ffb3f2a8fff	Vad 	PAGE_EXECUTE_WRITECOPY	4	0	0xffff840e9e0c65c0	\Windows\System32\netapi32.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9e7c91c0	0x7ffb44dc0000	0x7ffb44e57fff	Vad 	PAGE_EXECUTE_WRITECOPY	7	0	0xffff840e9e0c65c0	\Windows\System32\webio.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9f607940	0x7ffb459d0000	0x7ffb459f6fff	Vad 	PAGE_EXECUTE_WRITECOPY	3	0	0xffff840e9e7c91c0	\Windows\System32\samlib.dll	Disabled
# 14536	spoolsv.exe	0xffff840e98d43ee0	0x7ffb4dd20000	0x7ffb4e015fff	Vad 	PAGE_EXECUTE_WRITECOPY	35	0	0xffff840e9e7ca480	\Windows\System32\KernelBase.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9e7ca340	0x7ffb4d180000	0x7ffb4d1adfff	Vad 	PAGE_EXECUTE_WRITECOPY	7	0	0xffff840e98d43ee0	\Windows\System32\wldp.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9e7c8040	0x7ffb4cbc0000	0x7ffb4cbfafff	Vad 	PAGE_EXECUTE_WRITECOPY	6	0	0xffff840e9e7ca340	\Windows\System32\IPHLPAPI.DLL	Disabled
# 14536	spoolsv.exe	0xffff840e9786b490	0x7ffb49060000	0x7ffb49069fff	Vad 	PAGE_EXECUTE_WRITECOPY	3	0	0xffff840e9e7c8040	\Windows\System32\dsrole.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9e7c8cc0	0x7ffb46d10000	0x7ffb46d26fff	Vad 	PAGE_EXECUTE_WRITECOPY	3	0	0xffff840e9786b490	\Windows\System32\dhcpcsvc6.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9e7c8b80	0x7ffb47960000	0x7ffb4796afff	Vad 	PAGE_EXECUTE_WRITECOPY	2	0	0xffff840e9e7c8cc0	\Windows\System32\winnsi.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9e7c85e0	0x7ffb4c780000	0x7ffb4c889fff	Vad 	PAGE_EXECUTE_WRITECOPY	5	0	0xffff840e9786b490	\Windows\System32\winhttp.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9aa96780	0x7ffb4c920000	0x7ffb4c938fff	Vad 	PAGE_EXECUTE_WRITECOPY	4	0	0xffff840e9e7c85e0	\Windows\System32\wkscli.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9e7c82c0	0x7ffb4cee0000	0x7ffb4cf49fff	Vad 	PAGE_EXECUTE_WRITECOPY	4	0	0xffff840e9e7c8040	\Windows\System32\mswsock.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9786b0d0	0x7ffb4cc00000	0x7ffb4ccc9fff	Vad 	PAGE_EXECUTE_WRITECOPY	5	0	0xffff840e9e7c82c0	\Windows\System32\dnsapi.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9aa96d20	0x7ffb4ccd0000	0x7ffb4ccdbfff	Vad 	PAGE_EXECUTE_WRITECOPY	2	0	0xffff840e9786b0d0	\Windows\System32\netutils.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9e0cada0	0x7ffb4d0f0000	0x7ffb4d0fbfff	Vad 	PAGE_EXECUTE_WRITECOPY	3	0	0xffff840e9e7c82c0	\Windows\System32\cryptbase.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9e7c89a0	0x7ffb4d700000	0x7ffb4d731fff	Vad 	PAGE_EXECUTE_WRITECOPY	6	0	0xffff840e9e7ca340	\Windows\System32\sspicli.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9f606d60	0x7ffb4d680000	0x7ffb4d6cafff	Vad 	PAGE_EXECUTE_WRITECOPY	3	0	0xffff840e9e7c89a0	\Windows\System32\powrprof.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9f6071c0	0x7ffb4d660000	0x7ffb4d671fff	Vad 	PAGE_EXECUTE_WRITECOPY	3	0	0xffff840e9f606d60	\Windows\System32\umpdc.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9aa95560	0x7ffb4d6d0000	0x7ffb4d6fdfff	Vad 	PAGE_EXECUTE_WRITECOPY	4	0	0xffff840e9f606d60	\Windows\System32\userenv.dll	Disabled
# 14536	spoolsv.exe	0xffff840e98d4bc80	0x7ffb4d990000	0x7ffb4d9b1fff	Vad 	PAGE_EXECUTE_WRITECOPY	7	0	0xffff840e9e7c89a0	\Windows\System32\win32u.dll	Disabled
# 14536	spoolsv.exe	0xffff840e97866210	0x7ffb4d8f0000	0x7ffb4d98cfff	Vad 	PAGE_EXECUTE_WRITECOPY	7	0	0xffff840e98d4bc80	\Windows\System32\msvcp_win.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9aa947a0	0x7ffb4d760000	0x7ffb4d783fff	Vad 	PAGE_EXECUTE_WRITECOPY	3	0	0xffff840e97866210	\Windows\System32\profapi.dll	Disabled
# 14536	spoolsv.exe	0xffff840e97866b70	0x7ffb4daa0000	0x7ffb4dbb6fff	Vad 	PAGE_EXECUTE_WRITECOPY	9	0	0xffff840e98d4bc80	\Windows\System32\gdi32full.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9e7bfbc0	0x7ffb4da70000	0x7ffb4da96fff	Vad 	PAGE_EXECUTE_WRITECOPY	3	0	0xffff840e97866b70	\Windows\System32\bcrypt.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9e7bf120	0x7ffb4f050000	0x7ffb4f172fff	Vad 	PAGE_EXECUTE_WRITECOPY	15	0	0xffff840e98d43ee0	\Windows\System32\rpcrt4.dll	Disabled
# 14536	spoolsv.exe	0xffff840e97864550	0x7ffb4e570000	0x7ffb4e59afff	Vad 	PAGE_EXECUTE_WRITECOPY	4	0	0xffff840e9e7bf120	\Windows\System32\gdi32.dll	Disabled
# 14536	spoolsv.exe	0xffff840e97866d50	0x7ffb4e1b0000	0x7ffb4e24dfff	Vad 	PAGE_EXECUTE_WRITECOPY	10	0	0xffff840e97864550	\Windows\System32\msvcrt.dll	Disabled
# 14536	spoolsv.exe	0xffff840e97868010	0x7ffb4e020000	0x7ffb4e11ffff	Vad 	PAGE_EXECUTE_WRITECOPY	4	0	0xffff840e97866d50	\Windows\System32\ucrtbase.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9e7c9440	0x7ffb4e120000	0x7ffb4e1a1fff	Vad 	PAGE_EXECUTE_WRITECOPY	2	0	0xffff840e97868010	\Windows\System32\bcryptprimitives.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9e7c0020	0x7ffb4e450000	0x7ffb4e4fffff	Vad 	PAGE_EXECUTE_WRITECOPY	22	0	0xffff840e97866d50	\Windows\System32\advapi32.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9e7c7e60	0x7ffb4e2c0000	0x7ffb4e3eafff	Vad 	PAGE_EXECUTE_WRITECOPY	6	0	0xffff840e9e7c0020	\Windows\System32\ole32.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9e7c8ae0	0x7ffb4e500000	0x7ffb4e56afff	Vad 	PAGE_EXECUTE_WRITECOPY	7	0	0xffff840e9e7c0020	\Windows\System32\ws2_32.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9e7c5ac0	0x7ffb4ee20000	0x7ffb4ee4efff	Vad 	PAGE_EXECUTE_WRITECOPY	3	0	0xffff840e97864550	\Windows\System32\imm32.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9e7c9120	0x7ffb4edb0000	0x7ffb4edb7fff	Vad 	PAGE_EXECUTE_WRITECOPY	2	0	0xffff840e9e7c5ac0	\Windows\System32\nsi.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9e7c9a80	0x7ffb4e5a0000	0x7ffb4ed09fff	Vad 	PAGE_EXECUTE_WRITECOPY	16	0	0xffff840e9e7c9120	\Windows\System32\shell32.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9e7c87c0	0x7ffb4ef80000	0x7ffb4f04cfff	Vad 	PAGE_EXECUTE_WRITECOPY	6	0	0xffff840e9e7c5ac0	\Windows\System32\oleaut32.dll	Disabled
# 14536	spoolsv.exe	0xffff840e98d44160	0x7ffb4fac0000	0x7ffb4fb7cfff	Vad 	PAGE_EXECUTE_WRITECOPY	19	0	0xffff840e9e7bf120	\Windows\System32\kernel32.dll	Disabled
# 14536	spoolsv.exe	0xffff840e98d48b20	0x7ffb4f180000	0x7ffb4f31efff	Vad 	PAGE_EXECUTE_WRITECOPY	24	0	0xffff840e98d44160	\Windows\System32\user32.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9e7beae0	0x7ffb50090000	0x7ffb5012ffff	Vad 	PAGE_EXECUTE_WRITECOPY	6	0	0xffff840e98d44160	\Windows\System32\sechost.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9e7c8180	0x7ffb4fd30000	0x7ffb50082fff	Vad 	PAGE_EXECUTE_WRITECOPY	9	0	0xffff840e9e7beae0	\Windows\System32\combase.dll	Disabled
# 14536	spoolsv.exe	0xffff840e9cfb14e0	0x7ffb50170000	0x7ffb50367fff	Vad 	PAGE_EXECUTE_WRITECOPY	22	0	0xffff840e9e7beae0	\Windows\System32\ntdll.dll	Disabled
# Progress:    0.00		Scanning Elf64Layer using PageMapScanner
#
# Progress:    0.00		Scanning Elf64Layer using PageMapScanner
#
# Progress:   23.33		Scanning Elf64Layer using PageMapScanner
#
# Progress:    0.00		Scanning Elf64Layer using PageMapScanner
#
# Progress:  100.00		Stacking attempts finished
#
# Progress:    0.00		Scanning layer_name using PdbSignatureScanner
#
# Progress:    0.00		Scanning layer_name using PdbSignatureScanner
#
# Progress:  100.00		PDB scanning finished
# Volatility 3 Framework 2.26.2
#
# PID	Process	Start VPN	End VPN	Tag	Protection	CommitCharge	PrivateMemory	File output	Notes	Hexdump	Disasm
#
# 14536	spoolsv.exe	0xb70000	0xb70fff	VadS	PAGE_EXECUTE_READWRITE	1	1	Disabled	N/A
# fc 48 83 e4 f0 e8 cc 00 00 00 41 51 41 50 52 48 .H........AQAPRH
# 31 d2 65 48 8b 52 60 48 8b 52 18 51 48 8b 52 20 1.eH.R`H.R.QH.R
# 56 48 0f b7 4a 4a 4d 31 c9 48 8b 72 50 48 31 c0 VH..JJM1.H.rPH1.
# ac 3c 61 7c 02 2c 20 41 c1 c9 0d 41 01 c1 e2 ed .<a|., A...A....	fc 48 83 e4 f0 e8 cc 00 00 00 41 51 41 50 52 48 31 d2 65 48 8b 52 60 48 8b 52 18 51 48 8b 52 20 56 48 0f b7 4a 4a 4d 31 c9 48 8b 72 50 48 31 c0 ac 3c 61 7c 02 2c 20 41 c1 c9 0d 41 01 c1 e2 ed
# 14536	spoolsv.exe	0x3e00000	0x48e5fff	VadS	PAGE_EXECUTE_READWRITE	2790	1	Disabled	N/A
# 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 ................
# 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 ................
# 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 ................
# 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 ................	00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# 14536	spoolsv.exe	0x7fface510000	0x7fface511fff	VadS	PAGE_EXECUTE_READWRITE	2	1	Disabled	N/A
# 48 ff 25 89 be fb 7f ff 25 3b 00 00 00 cc cc cc H.%.....%;......
# cc cc cc cc cc cc cc cc cc cc cc cc cc cc 07 00 ................
# 48 ff 25 b9 44 06 00 00 00 00 00 00 00 00 00 00 H.%.D...........
# 00 00 00 00 00 00 00 00 00 00 00 00 00 00 07 00 ................	48 ff 25 89 be fb 7f ff 25 3b 00 00 00 cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc 07 00 48 ff 25 b9 44 06 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 07 00
# 14536	spoolsv.exe	0x7fff0000	0x170e38fff	VadS	PAGE_EXECUTE_READWRITE	986697	1	Disabled	N/A
# 48 83 c4 08 e8 80 a7 a7 00 80 a7 a7 00 00 00 00 H...............
# 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 ................
# 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 ................
# 00 00 00 00 00 00 00 00 00 a0 52 d2 55 f6 a3 22 ..........R.U.."	48 83 c4 08 e8 80 a7 a7 00 80 a7 a7 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 a0 52 d2 55 f6 a3 22
# 14536	spoolsv.exe	0x7ffaccc00000	0x7ffaccc00fff	VadS	PAGE_EXECUTE_READWRITE	1	1	Disabled	N/A
# 48 89 5c 24 08 ff 25 3d 00 00 00 cc cc cc cc cc H.\$..%=........
# cc cc cc cc cc cc cc cc cc cc cc cc cc cc 05 00 ................
# 48 89 5c 24 08 00 00 00 00 00 00 00 00 00 00 00 H.\$............
# 00 00 00 00 00 00 00 00 00 00 00 00 00 00 05 00 ................	48 89 5c 24 08 ff 25 3d 00 00 00 cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc 05 00 48 89 5c 24 08 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 05 00
# 14536	spoolsv.exe	0x7ffabf2b0000	0x7ffabf2b0fff	VadS	PAGE_EXECUTE_READWRITE	1	1	Disabled	N/A
# 48 89 5c 24 08 ff 25 3d 00 00 00 cc cc cc cc cc H.\$..%=........
# cc cc cc cc cc cc cc cc cc cc cc cc cc cc 05 00 ................
# 48 89 5c 24 08 00 00 00 00 00 00 00 00 00 00 00 H.\$............
# 00 00 00 00 00 00 00 00 00 00 00 00 00 00 05 00 ................	48 89 5c 24 08 ff 25 3d 00 00 00 cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc 05 00 48 89 5c 24 08 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 05 00
# 14536	spoolsv.exe	0x7ffaa6f60000	0x7ffaa6f60fff	VadS	PAGE_EXECUTE_READWRITE	1	1	Disabled	N/A
# 48 8b c4 48 89 58 08 ff 25 3b 00 00 00 cc cc cc H..H.X..%;......
# cc cc cc cc cc cc cc cc cc cc cc cc cc cc 07 00 ................
# 48 8b c4 48 89 58 08 00 00 00 00 00 00 00 00 00 H..H.X..........
# 00 00 00 00 00 00 00 00 00 00 00 00 00 00 07 00 ................	48 8b c4 48 89 58 08 ff 25 3b 00 00 00 cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc 07 00 48 8b c4 48 89 58 08 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 07 00
# 14536	spoolsv.exe	0x7ffabe790000	0x7ffabe790fff	VadS	PAGE_EXECUTE_READWRITE	1	1	Disabled	N/A
# 48 8b c4 4c 89 48 20 ff 25 3b 00 00 00 cc cc cc H..L.H .%;......
# cc cc cc cc cc cc cc cc cc cc cc cc cc cc 07 00 ................
# 48 8b c4 4c 89 48 20 00 00 00 00 00 00 00 00 00 H..L.H .........
# 00 00 00 00 00 00 00 00 00 00 00 00 00 00 07 00 ................	48 8b c4 4c 89 48 20 ff 25 3b 00 00 00 cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc 07 00 48 8b c4 4c 89 48 20 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 07 00
# 14536	spoolsv.exe	0x7ffacc890000	0x7ffacc890fff	VadS	PAGE_EXECUTE_READWRITE	1	1	Disabled	N/A
# 48 8b c4 48 89 58 10 ff 25 3b 00 00 00 cc cc cc H..H.X..%;......
# cc cc cc cc cc cc cc cc cc cc cc cc cc cc 07 00 ................
# 48 8b c4 48 89 58 10 00 00 00 00 00 00 00 00 00 H..H.X..........
# 00 00 00 00 00 00 00 00 00 00 00 00 00 00 07 00 ................	48 8b c4 48 89 58 10 ff 25 3b 00 00 00 cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc 07 00 48 8b c4 48 89 58 10 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 07 00
# 14536	spoolsv.exe	0x7ffacc940000	0x7ffacc940fff	VadS	PAGE_EXECUTE_READWRITE	1	1	Disabled	N/A
# 48 8b c4 48 89 58 10 ff 25 3b 00 00 00 cc cc cc H..H.X..%;......
# cc cc cc cc cc cc cc cc cc cc cc cc cc cc 07 00 ................
# 48 8b c4 48 89 58 10 00 00 00 00 00 00 00 00 00 H..H.X..........
# 00 00 00 00 00 00 00 00 00 00 00 00 00 00 07 00 ................	48 8b c4 48 89 58 10 ff 25 3b 00 00 00 cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc 07 00 48 8b c4 48 89 58 10 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 07 00
# 14536	spoolsv.exe	0x7ffacd9c0000	0x7ffacd9c0fff	VadS	PAGE_EXECUTE_READWRITE	1	1	Disabled	N/A
# 4c 8b d1 b8 03 10 00 00 ff 25 3a 00 00 00 cc cc L........%:.....
# cc cc cc cc cc cc cc cc cc cc cc cc cc cc 08 00 ................
# 4c 8b d1 b8 03 10 00 00 00 00 00 00 00 00 00 00 L...............
# 00 00 00 00 00 00 00 00 00 00 00 00 00 00 08 00 ................	4c 8b d1 b8 03 10 00 00 ff 25 3a 00 00 00 cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc 08 00 4c 8b d1 b8 03 10 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 08 00
# 14536	spoolsv.exe	0x7ffacd740000	0x7ffacd740fff	VadS	PAGE_EXECUTE_READWRITE	1	1	Disabled	N/A
# 48 89 5c 24 08 ff 25 3d 00 00 00 cc cc cc cc cc H.\$..%=........
# cc cc cc cc cc cc cc cc cc cc cc cc cc cc 05 00 ................
# 48 89 5c 24 08 00 00 00 00 00 00 00 00 00 00 00 H.\$............
# 00 00 00 00 00 00 00 00 00 00 00 00 00 00 05 00 ................	48 89 5c 24 08 ff 25 3d 00 00 00 cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc 05 00 48 89 5c 24 08 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 05 00
# 14536	spoolsv.exe	0x7fface020000	0x7fface021fff	VadS	PAGE_EXECUTE_READWRITE	2	1	Disabled	N/A
# 48 83 ec 28 4d 8b c8 ff 25 3b 00 00 00 cc cc cc H..(M...%;......
# cc cc cc cc cc cc cc cc cc cc cc cc cc cc 07 00 ................
# 48 83 ec 28 4d 8b c8 00 00 00 00 00 00 00 00 00 H..(M...........
# 00 00 00 00 00 00 00 00 00 00 00 00 00 00 07 00 ................	48 83 ec 28 4d 8b c8 ff 25 3b 00 00 00 cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc 07 00 48 83 ec 28 4d 8b c8 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 07 00
# 14536	spoolsv.exe	0x7ffad0370000	0x7ffad0370fff	VadS	PAGE_EXECUTE_READWRITE	1	1	Disabled	N/A
# 4c 8b d1 b8 79 00 00 00 ff 25 3a 00 00 00 cc cc L...y....%:.....
# cc cc cc cc cc cc cc cc cc cc cc cc cc cc 08 00 ................
# 4c 8b d1 b8 79 00 00 00 00 00 00 00 00 00 00 00 L...y...........
# 00 00 00 00 00 00 00 00 00 00 00 00 00 00 08 00 ................	4c 8b d1 b8 79 00 00 00 ff 25 3a 00 00 00 cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc 08 00 4c 8b d1 b8 79 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 08 00
# 14536	spoolsv.exe	0x7ffacf320000	0x7ffacf320fff	VadS	PAGE_EXECUTE_READWRITE	1	1	Disabled	N/A
# 48 83 ec 48 48 83 64 24 38 00 ff 25 38 00 00 00 H..HH.d$8..%8...
# cc cc cc cc cc cc cc cc cc cc cc cc cc cc 0a 00 ................
# 48 83 ec 48 48 83 64 24 38 00 00 00 00 00 00 00 H..HH.d$8.......
# 00 00 00 00 00 00 00 00 00 00 00 00 00 00 0a 00 ................	48 83 ec 48 48 83 64 24 38 00 ff 25 38 00 00 00 cc cc cc cc cc cc cc cc cc cc cc cc cc cc 0a 00 48 83 ec 48 48 83 64 24 38 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 0a 00
# 14536	spoolsv.exe	0x7ffacf180000	0x7ffacf180fff	VadS	PAGE_EXECUTE_READWRITE	1	1	Disabled	N/A
# 48 8b c4 48 89 58 08 ff 25 3b 00 00 00 cc cc cc H..H.X..%;......
# cc cc cc cc cc cc cc cc cc cc cc cc cc cc 07 00 ................
# 48 8b c4 48 89 58 08 00 00 00 00 00 00 00 00 00 H..H.X..........
# 00 00 00 00 00 00 00 00 00 00 00 00 00 00 07 00 ................	48 8b c4 48 89 58 08 ff 25 3b 00 00 00 cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc 07 00 48 8b c4 48 89 58 08 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 07 00
# 14536	spoolsv.exe	0x7fface570000	0x7fface570fff	VadS	PAGE_EXECUTE_READWRITE	1	1	Disabled	N/A
# 48 89 5c 24 08 ff 25 3d 00 00 00 cc cc cc cc cc H.\$..%=........
# cc cc cc cc cc cc cc cc cc cc cc cc cc cc 05 00 ................
# 48 89 5c 24 08 00 00 00 00 00 00 00 00 00 00 00 H.\$............
# 00 00 00 00 00 00 00 00 00 00 00 00 00 00 05 00 ................	48 89 5c 24 08 ff 25 3d 00 00 00 cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc 05 00 48 89 5c 24 08 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 05 00
# 14536	spoolsv.exe	0x7ffacfb80000	0x7ffacfb80fff	VadS	PAGE_EXECUTE_READWRITE	1	1	Disabled	N/A
# 4c 8b dc 48 83 ec 58 ff 25 3b 00 00 00 cc cc cc L..H..X.%;......
# cc cc cc cc cc cc cc cc cc cc cc cc cc cc 07 00 ................
# 4c 8b dc 48 83 ec 58 00 00 00 00 00 00 00 00 00 L..H..X.........
# 00 00 00 00 00 00 00 00 00 00 00 00 00 00 07 00 ................	4c 8b dc 48 83 ec 58 ff 25 3b 00 00 00 cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc cc 07 00 4c 8b dc 48 83 ec 58 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 07 00
# Progress:    0.00		Scanning Elf64Layer using PageMapScanner
#
# Progress:    0.00		Scanning Elf64Layer using PageMapScanner
#
# Progress:   23.33		Scanning Elf64Layer using PageMapScanner
#
# Progress:    0.00		Scanning Elf64Layer using PageMapScanner
#
# Progress:  100.00		Stacking attempts finished
#
# Progress:    0.00		Scanning layer_name using PdbSignatureScanner
#
# Progress:    0.00		Scanning layer_name using PdbSignatureScanner
#
# Progress:  100.00		PDB scanning finished
# C:\Users\vboxuser\repos\volatility3\volatility3\framework\deprecation.py:28: FutureWarning: This API (volatility3.plugins.windows.malware.malfind.Malfind.run) will be removed in the first release after 2026-06-07. This plugin has been renamed, please call volatility3.plugins.windows.malware.malfind.Malfind rather than volatility3.plugins.windows.malfind.Malfind.
#   warnings.warn(
# C:\Users\vboxuser\repos\volatility3\volatility3\framework\deprecation.py:105: FutureWarning: This plugin (volatility3.plugins.windows.malfind.Malfind) has been renamed and will be removed in the first release after 2026-06-07. Please ensure all method calls to this plugin are replaced with calls to volatility3.plugins.windows.malware.malfind.Malfind
#   warnings.warn(

# %% [markdown]
# # Analysis
#
# ## Loaded modules
#
# - Network stack/UI libraries present: `winhttp.dll`, `wininet.dll`, `webio.dll`, `ws2_32.dll`, `dnsapi.dll`, `mswsock.dll`
# - Script/.NET/AMSI chain: `mscoree.dll` (.NET CLR host), `amsi.dll` (Antimalware scan interface), `wldp.dll` (Code integrity/WDAC)
# - Odd/uncommon names in System32: `umppc19205.dll`, `CsXumd64_19205.dll`, `ScriptControl64_19205.dll`
#
# ## Malfind/VAD
#
# - RWX private region @ 0x0000000000B70000 (size 0x1000) with raw x64 code. First bytes are `fc 48 83 e4 f0 e8 cc 00 00 00 41 51 41 50 52 48 31 d2 65 48 8b 52 60 ...`. A code stube in an RWX page inside spoolsv is a classic footprint indicator of injected shellcode.
# - Numerous PAGE_EXECUTE_READWRITE regions and small thunk-like RWX stubs (e.g., at `0x7ffa...` ranges showing `48 FF 25 ...` RIP-relative jumps). Look like runtime trampolines/hooks.
# - Very large RWX reservation shown by VAD (e.g. `0x7FFF0000-...`), further reinforcing memory manipulation well beyond normal spooler behavior.
#
# ## Notes
#
# Evidence of code injection tino this spoolsv instance (RWX shellcode + trampolines), with capable networking and potential .NET hosting in-process.

# %%
# Handles / SIDs / privileges
# !python "{VOL}" -f "{IMG}" windows.handles --pid 14536
# !python "{VOL}" -f "{IMG}" windows.getsids --pid 14536
# !python "{VOL}" -f "{IMG}" windows.privileges --pid 14536
# Out:
# Volatility 3 Framework 2.26.2
#
# PID	Process	Offset	HandleValue	Type	GrantedAccess	Name
#
# 14536	spoolsv.exe	0x840e97fb1260	0x4	Event	0x1f0003	-
# 14536	spoolsv.exe	0xb70831f071d0	0x8	Key	0x9	MACHINE\SOFTWARE\MICROSOFT\WINDOWS NT\CURRENTVERSION\IMAGE FILE EXECUTION OPTIONS
# 14536	spoolsv.exe	0x840ea0858f70	0xc	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840e97fb14e0	0x10	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840e9817c300	0x14	WaitCompletionPacket	0x1	-
# 14536	spoolsv.exe	0x840ea0858880	0x18	IoCompletion	0x1f0003	-
# 14536	spoolsv.exe	0x840e97f1d900	0x1c	TpWorkerFactory	0xf00ff	-
# 14536	spoolsv.exe	0x840ea4eba850	0x20	IRTimer	0x100002	-
# 14536	spoolsv.exe	0x840e9817b460	0x24	WaitCompletionPacket	0x1	-
# 14536	spoolsv.exe	0x840ea4eb9310	0x28	IRTimer	0x100002	-
# 14536	spoolsv.exe	0x840e9817b530	0x2c	WaitCompletionPacket	0x1	-
# 14536	spoolsv.exe	0x840ea0858790	0x30	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea0858bf0	0x34	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea08592f0	0x38	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0xb708012fede0	0x3c	Directory	0x3	KnownDlls
# 14536	spoolsv.exe	0x840e97fb1860	0x40	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840e97fb1660	0x44	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840ea0858950	0x4c	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840e9b696a10	0x50	Mutant	0x1f0001	SM0:14536:304:WilStaging_02
# 14536	spoolsv.exe	0x840e9d82ede0	0x54	ALPC Port	0x1f0001	-
# 14536	spoolsv.exe	0xb708106aa500	0x58	Directory	0xf	BaseNamedObjects
# 14536	spoolsv.exe	0x840e98d47e70	0x5c	Semaphore	0x1f0003	SM0:14536:304:WilStaging_02_p0
# 14536	spoolsv.exe	0x840e98d491d0	0x60	Semaphore	0x1f0003	SM0:14536:304:WilStaging_02_p0h
# 14536	spoolsv.exe	0x840ea0859830	0x64	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea0858330	0x68	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea0858250	0x6c	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea0858400	0x70	IoCompletion	0x1f0003	-
# 14536	spoolsv.exe	0x840e9f302b00	0x74	TpWorkerFactory	0xf00ff	-
# 14536	spoolsv.exe	0x840ea4eb9860	0x78	IRTimer	0x100002	-
# 14536	spoolsv.exe	0x840e9817d820	0x7c	WaitCompletionPacket	0x1	-
# 14536	spoolsv.exe	0x840ea4eb9420	0x80	IRTimer	0x100002	-
# 14536	spoolsv.exe	0x840e9817d1a0	0x84	WaitCompletionPacket	0x1	-
# 14536	spoolsv.exe	0xb7081ad17950	0x88	Key	0x20019	MACHINE\SYSTEM\CONTROLSET001\CONTROL\NLS\SORTING\VERSIONS
# 14536	spoolsv.exe	0x840ea0859210	0x8c	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea0859670	0x90	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0xb70831f05960	0x94	Key	0x1	MACHINE\SYSTEM\CONTROLSET001\CONTROL\SESSION MANAGER
# 14536	spoolsv.exe	0x840ea0859c90	0x98	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840e9df4a260	0x9c	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840ea08593c0	0xa0	IoCompletion	0x1f0003	-
# 14536	spoolsv.exe	0x840e9a459c40	0xa4	WindowStation	0xf037f	WinSta0
# 14536	spoolsv.exe	0x840e96df9240	0xa8	Desktop	0xf01ff	Default
# 14536	spoolsv.exe	0x840e9a459c40	0xac	WindowStation	0xf037f	WinSta0
# 14536	spoolsv.exe	0x840ea0c05920	0xb0	File	0x100001	\Device\HarddiskVolume3\Windows\System32\en-US\spoolsv.exe.mui
# 14536	spoolsv.exe	0x840ea0859910	0xb4	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea0859bb0	0xb8	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea08584f0	0xbc	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea08594b0	0xc0	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840e9df4a460	0xc4	Semaphore	0x100003	-
# 14536	spoolsv.exe	0x840e9df4a2e0	0xc8	Semaphore	0x100003	-
# 14536	spoolsv.exe	0x840e923a5260	0xcc	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840ea0c074c0	0xd0	File	0x100003	\Device\KsecDD
# 14536	spoolsv.exe	0x840ea0859d70	0xd4	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea0858cd0	0xd8	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea0859750	0xdc	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea08586b0	0xe0	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea0859590	0xe4	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea0858a30	0xe8	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840e923ab9e0	0xec	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840ea08585d0	0xf0	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea0c0ada0	0xf4	File	0x100080	\Device\Nsi
# 14536	spoolsv.exe	0xb7081ad19a40	0xf8	Key	0xf003f	MACHINE
# 14536	spoolsv.exe	0xb7081ad1a5f0	0xfc	Key	0x20019	MACHINE\SYSTEM\CONTROLSET001\SERVICES\TCPIP\PARAMETERS\INTERFACES
# 14536	spoolsv.exe	0xb7081ad19930	0x100	Key	0x20019	MACHINE\SYSTEM\CONTROLSET001\SERVICES\TCPIP6\PARAMETERS\INTERFACES
# 14536	spoolsv.exe	0x840ea0858db0	0x104	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea08599f0	0x108	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea0858e90	0x10c	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea085b0b0	0x110	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea085b890	0x114	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea085a390	0x118	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea085b510	0x11c	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea085a0f0	0x120	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840e9c702be0	0x124	Event	0x1f0003	-
# 14536	spoolsv.exe	0xb7081ad1b6f0	0x128	Key	0xf003f	USER\S-1-12-1-419028606-1323772725-945580434-2117921032
# 14536	spoolsv.exe	0x840ea085aa90	0x12c	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea085a7f0	0x130	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea085b970	0x134	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840e98c7a080	0x138	Thread	0x1fffff	Tid 14952 Pid 14536
# 14536	spoolsv.exe	0x840e9c702c60	0x13c	Event	0x1f0003	-
# 14536	spoolsv.exe	0xb7081ad1c080	0x140	Key	0xf003f	MACHINE\SYSTEM\CONTROLSET001\SERVICES\WINSOCK2\PARAMETERS\PROTOCOL_CATALOG9
# 14536	spoolsv.exe	0x840e9c703ee0	0x144	Event	0x1f0003	-
# 14536	spoolsv.exe	0xb7081ad1d290	0x148	Key	0xf003f	MACHINE\SYSTEM\CONTROLSET001\SERVICES\WINSOCK2\PARAMETERS\NAMESPACE_CATALOG5
# 14536	spoolsv.exe	0x840e9c7043e0	0x14c	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840eaa187da0	0x150	WaitCompletionPacket	0x1	-
# 14536	spoolsv.exe	0xb7081485c2b0	0x154	Key	0x20019	MACHINE\SOFTWARE\POLICIES\MICROSOFT\WINDOWS
# 14536	spoolsv.exe	0x840e9c7045e0	0x158	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840eaa188690	0x15c	WaitCompletionPacket	0x1	-
# 14536	spoolsv.exe	0x840e9c7047e0	0x160	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840ea085ae10	0x164	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea085a1d0	0x168	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea085b430	0x16c	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840e9e3ca0e0	0x170	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840ea085a630	0x174	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea085a550	0x178	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840e9e3ccfe0	0x17c	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840e9e3ccce0	0x180	Event	0x1f0003	-
# 14536	spoolsv.exe	0xb70813f98440	0x184	Key	0x20019	MACHINE\SOFTWARE\MICROSOFT\OLE
# 14536	spoolsv.exe	0xb70813f9a310	0x188	Key	0x20019	MACHINE
# 14536	spoolsv.exe	0x840eaa18a570	0x18c	WaitCompletionPacket	0x1	-
# 14536	spoolsv.exe	0x840e9c705760	0x190	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840e98c7a080	0x194	Thread	0x1fffff	Tid 14952 Pid 14536
# 14536	spoolsv.exe	0x840ea085a2b0	0x198	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840e9c7048e0	0x19c	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840e9e3cc560	0x1a4	Event	0x1f0003	-
# 14536	spoolsv.exe	0xb70831f25430	0x1a8	Key	0x10	MACHINE\SOFTWARE\POLICIES\MICROSOFT\WINDOWS\TENANTRESTRICTIONS\PAYLOAD
# 14536	spoolsv.exe	0x840e9e3cc7e0	0x1ac	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840e9e3cc860	0x1b0	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840ea085caf0	0x1b4	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea0860830	0x1b8	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea085fcd0	0x1bc	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea085f870	0x1c4	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea085fdb0	0x1c8	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea0860670	0x1cc	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0xb70813f98660	0x1d0	Key	0x20019	MACHINE\SYSTEM\CONTROLSET001\CONTROL\NLS\SORTING\IDS
# 14536	spoolsv.exe	0x840ea0860bb0	0x1d4	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea0860ad0	0x1d8	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea085ff70	0x1dc	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea0c0b0e0	0x1e4	File	0x100001	\Device\CNG
# 14536	spoolsv.exe	0x840ea085f250	0x1e8	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0xb70813f98bb0	0x1f0	Key	0xf003f	USER
# 14536	spoolsv.exe	0x840ea085f5d0	0x1f4	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea0860750	0x1f8	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea085fe90	0x1fc	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea085f4f0	0x200	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea0860c90	0x204	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840e9e3cdb60	0x208	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840e9c0d7dd0	0x20c	ALPC Port	0x1f0001	-
# 14536	spoolsv.exe	0x840e9e3ca060	0x210	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840ea0861100	0x214	IoCompletion	0x1f0003	-
# 14536	spoolsv.exe	0x840e99797b50	0x218	TpWorkerFactory	0xf00ff	-
# 14536	spoolsv.exe	0x840ea0860e50	0x21c	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea0862890	0x220	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea08625f0	0x224	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea08626d0	0x228	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea0862970	0x22c	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840e9ce6a800	0x230	ALPC Port	0x1f0001	-
# 14536	spoolsv.exe	0x840e9c1cbdd0	0x244	ALPC Port	0x1f0001	-
# 14536	spoolsv.exe	0x840e9e3cdee0	0x248	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840e9e3cdf60	0x24c	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840e9e3cd8e0	0x250	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840eaa184800	0x254	WaitCompletionPacket	0x1	-
# 14536	spoolsv.exe	0x840e9e3d1c60	0x258	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840eaa184a70	0x25c	WaitCompletionPacket	0x1	-
# 14536	spoolsv.exe	0x840e9e3d28e0	0x260	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840e9e3d3f60	0x264	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840e9e3d32e0	0x268	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840eaa184ce0	0x26c	WaitCompletionPacket	0x1	-
# 14536	spoolsv.exe	0x840e9e3d3660	0x270	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840e9e3d36e0	0x274	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840e9e3d3760	0x278	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840eaa184e80	0x27c	WaitCompletionPacket	0x1	-
# 14536	spoolsv.exe	0x840e9e3d4ae0	0x280	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840e9e3d4be0	0x284	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840e9e3d50e0	0x288	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840eaa1850f0	0x28c	WaitCompletionPacket	0x1	-
# 14536	spoolsv.exe	0x840ea0862270	0x290	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840e9c35e980	0x294	File	0x100001	\Device\HarddiskVolume3\Windows\System32\en-US\winnlsres.dll.mui
# 14536	spoolsv.exe	0x840e9e3d42e0	0x298	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840ea0861470	0x29c	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840e9e3d4fe0	0x2a0	Semaphore	0x100003	-
# 14536	spoolsv.exe	0x840e9e3ce0e0	0x2a4	Semaphore	0x100003	-
# 14536	spoolsv.exe	0x840ea08602f0	0x2a8	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0xb70806c521a0	0x2ac	Section	0x4	F932B6C7-3A20-46A0-B8A0-8894AA421973
# 14536	spoolsv.exe	0x840ea06067c0	0x2b4	File	0x16019f	\Device\Afd\Endpoint
# 14536	spoolsv.exe	0x840ea0609bc0	0x2b8	File	0x100001	\Device\HarddiskVolume3\Windows\System32\en-US\mswsock.dll.mui
# 14536	spoolsv.exe	0x840e9c84c3e0	0x2bc	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840ea1848180	0x2c8	File	0x100001	\Device\HarddiskVolume3\Windows\System32\en-US\KernelBase.dll.mui
# 14536	spoolsv.exe	0x840e9df4b0e0	0x2cc	Semaphore	0x100003	-
# 14536	spoolsv.exe	0x840ea0861550	0x2d0	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840e9e602dd0	0x2d4	ALPC Port	0x1f0001	-
# 14536	spoolsv.exe	0x840e9df4a7e0	0x2d8	Semaphore	0x100003	-
# 14536	spoolsv.exe	0x840ea0862190	0x2dc	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840e9e7c9350	0x2e0	Mutant	0x1f0001	-
# 14536	spoolsv.exe	0x840ea08620b0	0x2e4	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea0862350	0x2e8	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea0861ef0	0x2ec	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea0860f30	0x2f0	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea08627b0	0x2f4	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea0862510	0x2f8	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea08619b0	0x2fc	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea4ebbb70	0x300	IRTimer	0x100002	-
# 14536	spoolsv.exe	0x840e98187eb0	0x304	WaitCompletionPacket	0x1	-
# 14536	spoolsv.exe	0x840ea4ebcb60	0x308	IRTimer	0x100002	-
# 14536	spoolsv.exe	0x840e98187f80	0x30c	WaitCompletionPacket	0x1	-
# 14536	spoolsv.exe	0x840e9dc9c080	0x310	Thread	0x1fffff	Tid 15528 Pid 14536
# 14536	spoolsv.exe	0x840ea08611d0	0x314	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea0861390	0x318	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea0861630	0x31c	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea0861710	0x320	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea0a67120	0x324	File	0x100001	\Device\KsecDD
# 14536	spoolsv.exe	0x840ea08617f0	0x328	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840ea08618d0	0x32c	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840e9c9267e0	0x330	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840e996f2810	0x334	ALPC Port	0x1f0001	-
# 14536	spoolsv.exe	0x840ea085bec0	0x338	IoCompletion	0x1f0003	-
# 14536	spoolsv.exe	0x840e91f118f0	0x33c	TpWorkerFactory	0xf00ff	-
# 14536	spoolsv.exe	0x840ea1943980	0x340	IRTimer	0x100002	-
# 14536	spoolsv.exe	0x840eaa1884f0	0x344	WaitCompletionPacket	0x1	-
# 14536	spoolsv.exe	0x840ea1945300	0x348	IRTimer	0x100002	-
# 14536	spoolsv.exe	0x840eaa188350	0x34c	WaitCompletionPacket	0x1	-
# 14536	spoolsv.exe	0x840e9dc9c080	0x350	Thread	0x1fffff	Tid 15528 Pid 14536
# 14536	spoolsv.exe	0x840ea1943210	0x354	IRTimer	0x100003	-
# 14536	spoolsv.exe	0x840e99d28080	0x358	Thread	0x1fffff	Tid 11300 Pid 14536
# 14536	spoolsv.exe	0x840ea4eb9a80	0x35c	IRTimer	0x100003	-
# 14536	spoolsv.exe	0x840e991f2080	0x360	Thread	0x1fffff	Tid 11096 Pid 14536
# 14536	spoolsv.exe	0x840ea4eba410	0x364	IRTimer	0x100003	-
# 14536	spoolsv.exe	0x840e9c926360	0x368	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840e9c927760	0x36c	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840ea53490e0	0x370	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840e9937b080	0x374	Thread	0x1fffff	Tid 15828 Pid 14536
# 14536	spoolsv.exe	0x840ea4ebd0b0	0x378	IRTimer	0x100003	-
# 14536	spoolsv.exe	0x840ea53485e0	0x37c	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840ea5348b60	0x380	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840ea53492e0	0x384	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840ea7058080	0x388	Thread	0x1fffff	Tid 15972 Pid 14536
# 14536	spoolsv.exe	0x840ea4ebd1c0	0x38c	IRTimer	0x100003	-
# 14536	spoolsv.exe	0x840ea5349660	0x390	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840ea53498e0	0x394	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840e9954f080	0x398	Thread	0x1fffff	Tid 15116 Pid 14536
# 14536	spoolsv.exe	0x840ea4ebba60	0x39c	IRTimer	0x100003	-
# 14536	spoolsv.exe	0x840ea5349860	0x3a0	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840ea534a0e0	0x3a4	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840e9dc9c080	0x3a8	Thread	0x1fffff	Tid 15528 Pid 14536
# 14536	spoolsv.exe	0x840ea5349560	0x3ac	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840ea7058080	0x3b0	Thread	0x1fffff	Tid 15972 Pid 14536
# 14536	spoolsv.exe	0x840ea53495e0	0x3b4	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840ea085bf80	0x3b8	IoCompletion	0x1f0003	-
# 14536	spoolsv.exe	0x840ea7058080	0x3bc	Thread	0x1fffff	Tid 15972 Pid 14536
# 14536	spoolsv.exe	0x840ea5351fe0	0x3c0	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840ea534b0e0	0x3c4	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840ea5349ee0	0x3c8	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840e9937b080	0x3cc	Thread	0x1fffff	Tid 15828 Pid 14536
# 14536	spoolsv.exe	0x840ea3cdfde0	0x3d0	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840e9954f080	0x3d4	Thread	0x1fffff	Tid 15116 Pid 14536
# 14536	spoolsv.exe	0x840ea5351f60	0x3d8	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840e9954f080	0x3dc	Thread	0x1fffff	Tid 15116 Pid 14536
# 14536	spoolsv.exe	0x840e9f7a43f0	0x3e4	EtwRegistration	0x804	-
# 14536	spoolsv.exe	0x840e99c13260	0x3e8	Semaphore	0x100003	-
# 14536	spoolsv.exe	0x840ea46e4ee0	0x3f4	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840e99c13560	0x3fc	Semaphore	0x100003	-
# 14536	spoolsv.exe	0x840e99d28080	0x404	Thread	0x1fffff	Tid 11300 Pid 14536
# 14536	spoolsv.exe	0x840e991f2080	0x40c	Thread	0x1fffff	Tid 11096 Pid 14536
# 14536	spoolsv.exe	0x840e97fac660	0x410	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840e9c5aabe0	0x420	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840e9fe44a40	0x424	File	0x16019f	\Device\Afd\Endpoint
# 14536	spoolsv.exe	0x840e9f43d3e0	0x428	File	0x100020	\Device\HarddiskVolume3\Users\IanVeep\AppData\Roaming\Microsoft\Windows\Start Menu\Programs\Startup
# 14536	spoolsv.exe	0x840e9c928760	0x434	Event	0x1f0003	-
# 14536	spoolsv.exe	0x840e9dc9c080	0x438	Thread	0x1fffff	Tid 15528 Pid 14536
# 14536	spoolsv.exe	0xb7080a315a80	0x440	Key	0x1	MACHINE\SYSTEM\HARDWARECONFIG
# 14536	spoolsv.exe	0x840e9f7a45b0	0x448	EtwRegistration	0x804	-
# Progress:    0.00		Scanning Elf64Layer using PageMapScanner
#
# Progress:    0.00		Scanning Elf64Layer using PageMapScanner
#
# Progress:   23.33		Scanning Elf64Layer using PageMapScanner
#
# Progress:    0.00		Scanning Elf64Layer using PageMapScanner
#
# Progress:  100.00		Stacking attempts finished
#
# Progress:    0.00		Scanning layer_name using PdbSignatureScanner
#
# Progress:    0.00		Scanning layer_name using PdbSignatureScanner
#
# Progress:  100.00		PDB scanning finished
# Volatility 3 Framework 2.26.2
#
# PID	Process	SID	Name
#
# 14536	spoolsv.exe	S-1-12-1-419028606-1323772725-945580434-2117921032	IanVeep
# 14536	spoolsv.exe	S-1-16-12288	High Mandatory Level
# 14536	spoolsv.exe	S-1-1-0	Everyone
# 14536	spoolsv.exe	S-1-5-32-544	Administrators
# 14536	spoolsv.exe	S-1-5-32-545	Users
# 14536	spoolsv.exe	S-1-5-4	Interactive
# 14536	spoolsv.exe	S-1-2-1	Console Logon (Users who are logged onto the physical console)
# 14536	spoolsv.exe	S-1-5-11	Authenticated Users
# 14536	spoolsv.exe	S-1-5-15	This Organization
# 14536	spoolsv.exe	S-1-5-5-0-40037722	Logon Session
# 14536	spoolsv.exe	S-1-2-0	Local (Users with the ability to log in locally)
# 14536	spoolsv.exe	S-1-5-64-36	-
# Progress:    0.00		Scanning Elf64Layer using PageMapScanner
#
# Progress:    0.00		Scanning Elf64Layer using PageMapScanner
#
# Progress:   23.33		Scanning Elf64Layer using PageMapScanner
#
# Progress:    0.00		Scanning Elf64Layer using PageMapScanner
#
# Progress:  100.00		Stacking attempts finished
#
# Progress:    0.00		Scanning layer_name using PdbSignatureScanner
#
# Progress:    0.00		Scanning layer_name using PdbSignatureScanner
#
# Progress:  100.00		PDB scanning finished
# Volatility 3 Framework 2.26.2
#
# PID	Process	Value	Privilege	Attributes	Description
#
# 14536	spoolsv.exe	2	SeCreateTokenPrivilege		Create a token object
# 14536	spoolsv.exe	3	SeAssignPrimaryTokenPrivilege		Replace a process-level token
# 14536	spoolsv.exe	4	SeLockMemoryPrivilege		Lock pages in memory
# 14536	spoolsv.exe	5	SeIncreaseQuotaPrivilege	Present	Increase quotas
# 14536	spoolsv.exe	6	SeMachineAccountPrivilege		Add workstations to the domain
# 14536	spoolsv.exe	7	SeTcbPrivilege		Act as part of the operating system
# 14536	spoolsv.exe	8	SeSecurityPrivilege	Present	Manage auditing and security log
# 14536	spoolsv.exe	9	SeTakeOwnershipPrivilege	Present	Take ownership of files/objects
# 14536	spoolsv.exe	10	SeLoadDriverPrivilege	Present	Load and unload device drivers
# 14536	spoolsv.exe	11	SeSystemProfilePrivilege	Present	Profile system performance
# 14536	spoolsv.exe	12	SeSystemtimePrivilege	Present	Change the system time
# 14536	spoolsv.exe	13	SeProfileSingleProcessPrivilege	Present	Profile a single process
# 14536	spoolsv.exe	14	SeIncreaseBasePriorityPrivilege	Present	Increase scheduling priority
# 14536	spoolsv.exe	15	SeCreatePagefilePrivilege	Present	Create a pagefile
# 14536	spoolsv.exe	16	SeCreatePermanentPrivilege		Create permanent shared objects
# 14536	spoolsv.exe	17	SeBackupPrivilege	Present	Backup files and directories
# 14536	spoolsv.exe	18	SeRestorePrivilege	Present	Restore files and directories
# 14536	spoolsv.exe	19	SeShutdownPrivilege	Present	Shut down the system
# 14536	spoolsv.exe	20	SeDebugPrivilege	Present,Enabled	Debug programs
# 14536	spoolsv.exe	21	SeAuditPrivilege		Generate security audits
# 14536	spoolsv.exe	22	SeSystemEnvironmentPrivilege	Present	Edit firmware environment values
# 14536	spoolsv.exe	23	SeChangeNotifyPrivilege	Present,Enabled,Default	Receive notifications of changes to files or directories
# 14536	spoolsv.exe	24	SeRemoteShutdownPrivilege	Present	Force shutdown from a remote system
# 14536	spoolsv.exe	25	SeUndockPrivilege	Present	Remove computer from docking station
# 14536	spoolsv.exe	26	SeSyncAgentPrivilege		Synch directory service data
# 14536	spoolsv.exe	27	SeEnableDelegationPrivilege		Enable user accounts to be trusted for delegation
# 14536	spoolsv.exe	28	SeManageVolumePrivilege	Present	Manage the files on a volume
# 14536	spoolsv.exe	29	SeImpersonatePrivilege	Present,Enabled,Default	Impersonate a client after authentication
# 14536	spoolsv.exe	30	SeCreateGlobalPrivilege	Present,Enabled,Default	Create global objects
# 14536	spoolsv.exe	31	SeTrustedCredManAccessPrivilege		Access Credential Manager as a trusted caller
# 14536	spoolsv.exe	32	SeRelabelPrivilege		Modify the mandatory integrity level of an object
# 14536	spoolsv.exe	33	SeIncreaseWorkingSetPrivilege	Present	Allocate more memory for user applications
# 14536	spoolsv.exe	34	SeTimeZonePrivilege	Present	Adjust the time zone of the computer's internal clock
# 14536	spoolsv.exe	35	SeCreateSymbolicLinkPrivilege	Present	Required to create a symbolic link
# 14536	spoolsv.exe	36	SeDelegateSessionUserImpersonatePrivilege	Present	Obtain an impersonation token for another user in the same session.
# Progress:    0.00		Scanning Elf64Layer using PageMapScanner
#
# Progress:    0.00		Scanning Elf64Layer using PageMapScanner
#
# Progress:   23.33		Scanning Elf64Layer using PageMapScanner
#
# Progress:    0.00		Scanning Elf64Layer using PageMapScanner
#
# Progress:  100.00		Stacking attempts finished
#
# Progress:    0.00		Scanning layer_name using PdbSignatureScanner
#
# Progress:    0.00		Scanning layer_name using PdbSignatureScanner
#
# Progress:  100.00		PDB scanning finished

# %% [markdown]
# # Analysis
#
# ## Handles
#
# - File handle to Startup folder `\Device\HarddiskVolume3\Users\IanVeep\AppData\Roaming\Microsoft\Windows\Start Menu\Programs\Startup` is a strong hint of user-context persistence (dropper/LNK staging)
# - AFD endpoints (`\Device\Afd\Endpoint`) indicate active/ready sockets
# - GUID-named Section `F932B6C7-3A20-46A0-B8A0-8894AA421973` is uncommon
#
# ## SIDs
#
# - Includes user SID IanVeep and interactive groups, plus admin groups; unusual for a “service” spooler instance that should be running under SYSTEM/Session 0. Indicates interactive/session-tied context.
#
# ## Privileges
#
# - High-risk privileges present and enabled: `SeDebugPrivilege`, `SeImpersonatePrivilege`, plus many SYSTEM-level privileges (`SeTcbPrivilege`, `SeLoadDriverPrivilege`, etc.).
# - Together with Session 2 lineage, this suggests the process is running with elevated/system-like capabilities in a user session (token abuse/impersonation or spawned as high-priv).
#
# ## Notes
#
# Token/privilege profile and a startup-folder handle support post-exploitation objectives.

# %%
# Network corroboration ; recap from lab 2
# !python "{VOL}" -f "{IMG}" windows.netscan | findstr /i "14536"
# Out:
# 0x840e97632010	TCPv4	10.20.20.23	59865	35.86.58.69	80	CLOSED	14536	spoolsv.exe	2025-03-17 17:26:37.000000 UTC
# 0x840e99cb76e0	TCPv4	10.20.20.23	59879	35.86.58.69	80	CLOSED	14536	spoolsv.exe	2025-03-17 17:27:04.000000 UTC
# 0x840e99d64b60	TCPv4	10.20.20.23	59867	35.86.58.69	80	CLOSED	14536	spoolsv.exe	2025-03-17 17:26:39.000000 UTC
# 0x840e99d66520	TCPv4	10.20.20.23	59329	35.86.58.69	4444	CLOSED	14536	spoolsv.exe	2025-03-17 17:12:10.000000 UTC
# 0x840e9b199a70	TCPv4	10.20.20.23	59883	35.86.58.69	80	CLOSED	14536	spoolsv.exe	2025-03-17 17:27:06.000000 UTC
# 0x840e9b2dd010	TCPv4	10.20.20.23	59882	35.86.58.69	80	CLOSED	14536	spoolsv.exe	2025-03-17 17:27:06.000000 UTC
# 0x840e9bdeca20	TCPv4	10.20.20.23	59884	35.86.58.69	80	ESTABLISHED	14536	spoolsv.exe	2025-03-17 17:27:09.000000 UTC
# 0x840e9ce6c880	TCPv4	10.20.20.23	59881	35.86.58.69	80	CLOSED	14536	spoolsv.exe	2025-03-17 17:27:06.000000 UTC
# 0x840e9ea7da20	TCPv4	10.20.20.23	59875	35.86.58.69	80	CLOSED	14536	spoolsv.exe	2025-03-17 17:26:49.000000 UTC
# Progress:    0.00		Scanning Elf64Layer using PageMapScanner
#
# Progress:    0.00		Scanning Elf64Layer using PageMapScanner
#
# Progress:   23.33		Scanning Elf64Layer using PageMapScanner
#
# Progress:    0.00		Scanning Elf64Layer using PageMapScanner
#
# Progress:  100.00		Stacking attempts finished
#
# Progress:    0.00		Scanning layer_name using PdbSignatureScanner
#
# Progress:    0.00		Scanning layer_name using PdbSignatureScanner
#
# Progress:  100.00		PDB scanning finished

# %% [markdown]
# # Recap from lab 2
# - CLOSED 10.20.20.23:59329 -> 35.86.58.69:4444 at 17:12:10 (same minute this spoolsv starts).
# - Multiple HTTP sessions to the same host:
#   - CLOSED 10.20.20.23:59867/59865/59883/59882/59881 -> 35.86.58.69:80 around 17:26:37–17:27:06.
#   - ESTABLISHED 10.20.20.23:59884 -> 35.86.58.69:80 at 17:27:09.
# - Port 4444 and repeated hits to the same external IP are red flags for C2/handshake behavior.
# - Legitimate print spooler traffic doesn’t originate as a child of PowerShell in a user session, and it typically doesn’t initiate outbound HTTP/4444 to the internet.
# - The legit print spooler (spoolsv.exe PID 2904) is also present and only listens on RPC/ephemeral (LISTEN 0.0.0.0:49668), which is normal. Distinguish it from the rogue one by PID/parent/session and its outbound connections.

# %%
PID   = 14536                                     # target PID (e.g., rogue spoolsv.exe)
CARVE_START = 0x0000000000B70000                  # target VA (e.g., from malfind)
CARVE_SIZE  = 0x1000                              # bytes to carve from that VA

DUMP_DIR = CASE_DIR / "dumps" / f"pid_{PID}_memmap"
DUMP_DIR.mkdir(parents=True, exist_ok=True)

# Produce the dump file
#rc, so, se = run_cmd(f'python "{VOL}" -f "{IMG}" -o "{DUMP_DIR}" windows.memmap --pid {PID} --dump', live=False, timeout=3600)
if rc != 0:
    raise RuntimeError(f"volatility memmap --dump failed (rc={rc})")
dump_files = sorted(DUMP_DIR.glob("*.dmp"))
dump_path = dump_files[0]
print("Dump file:", dump_path)

# Get mapping table
#rc, map_out, map_err = run(f'python "{VOL}" -f "{IMG}" windows.memmap --pid {PID}', live=False, timeout=3600)
if rc != 0:
    # Some builds write table to stderr; try to use either
    if not map_out and map_err:
        map_out = map_err
    if not map_out:
        raise RuntimeError("Failed to obtain memmap table output")

# Parse rows and locate CARVE_START range to compute file offset
# Accept either header variants that include 'InFile' or 'Offset'
# Typical columns: Virtual Physical Size Offset InFile ...
line_re = re.compile(r'^\s*([0-9A-Fa-fx]+)\s+([0-9A-Fa-fx]+)\s+([0-9A-Fa-fx]+)\s+([0-9A-Fa-fx]+)\s+([0-9A-Fa-fx]+)')
rows = []
for line in map_out.splitlines():
    # Heuristic: pick lines that look like 5 hex columns
    m = line_re.match(line.strip())
    if not m:
        continue
    virtual = int(m.group(1), 16)
    physical = int(m.group(2), 16)
    size     = int(m.group(3), 16)
    offset   = int(m.group(4), 16)  # this may already be "InFile" in some builds
    infile   = int(m.group(5), 16)
    # Prefer the last column as "in-file" offset if it’s non-zero; else use the 4th
    file_off = infile if infile != 0 else offset
    rows.append((virtual, size, file_off))

if not rows:
    raise RuntimeError("Could not parse any memmap rows to compute file offsets.")

# Find the row whose VA range contains CARVE_START
file_offset = None
row_size = None
for va, sz, off in rows:
    if va <= CARVE_START < va + sz:
        file_offset = off + (CARVE_START - va)
        row_size = sz - (CARVE_START - va)
        break

if file_offset is None:
    # As a fallback, try exact-match rows (rare)
    for va, sz, off in rows:
        if va == CARVE_START:
            file_offset = off
            row_size = sz
            break

if file_offset is None:
    raise RuntimeError(f"Could not locate VA 0x{CARVE_START:x} in memmap table.")

# Carve bytes from the single dump
carve_len = min(CARVE_SIZE, row_size if row_size else CARVE_SIZE)
carve_path = DUMP_DIR / f"pid_{PID}_carve_0x{CARVE_START:x}.bin"
with open(dump_path, "rb") as f, open(carve_path, "wb") as g:
    f.seek(file_offset)
    g.write(f.read(carve_len))

print(f"Carved {carve_len} bytes from VA 0x{CARVE_START:x} @ file offset 0x{file_offset:x}")
print("Carve path:", carve_path)
# Out:
# Dump file: C:\Users\vboxuser\repos\CYBS-5014\lab3\output\dumps\pid_14536_memmap\pid.14536-1.dmp
# Carved 4096 bytes from VA 0xb70000 @ file offset 0xd
# Carve path: C:\Users\vboxuser\repos\CYBS-5014\lab3\output\dumps\pid_14536_memmap\pid_14536_carve_0xb70000.bin

# %% [markdown]
# # Analysis
#
# - Saved full memmap dump and carved 0xB70000 shellcode page for static triage.
# - Carve method: translated VA in-file offset using `windows.memmap` table to precise extraction.

# %% [markdown]
# # Hash PID Dumps

# %%
artifacts = []
for p in sorted(DUMP_DIR.glob("**/*")):
    if p.is_file():
        artifacts.append({
            "file": str(p),
            "size": p.stat().st_size,
            "sha256": sha256(p),
            "mtime_utc": time.strftime("%Y-%m-%d %H:%M:%SZ", time.gmtime(p.stat().st_mtime))
        })

print(json.dumps(artifacts, indent=2))
# Out:
# [
#   {
#     "file": "C:\\Users\\vboxuser\\repos\\CYBS-5014\\lab3\\output\\dumps\\pid_14536_memmap\\pid.14536-1.dmp",
#     "size": 1930354688,
#     "sha256": "a3ffb85d91af9c0eaf06f96273acf01b2bed51c0ae3e00c91ea97b1bbe345b05",
#     "mtime_utc": "2025-11-02 22:56:00Z"
#   },
#   {
#     "file": "C:\\Users\\vboxuser\\repos\\CYBS-5014\\lab3\\output\\dumps\\pid_14536_memmap\\pid.14536.dmp",
#     "size": 1930354688,
#     "sha256": "a3ffb85d91af9c0eaf06f96273acf01b2bed51c0ae3e00c91ea97b1bbe345b05",
#     "mtime_utc": "2025-11-02 22:49:14Z"
#   },
#   {
#     "file": "C:\\Users\\vboxuser\\repos\\CYBS-5014\\lab3\\output\\dumps\\pid_14536_memmap\\pid_14536_carve_0xb70000.bin",
#     "size": 4096,
#     "sha256": "96e7a618d024c2e87e0c8ee4f3cd41e68f7c7b61898b44395d04e9b35334cace",
#     "mtime_utc": "2025-11-02 23:06:42Z"
#   }
# ]

# %% [markdown]
# # Static Analysis of Dumps

# %%
SAMPLES_DIR = DUMP_DIR
REPORT_DIR  = CASE_DIR / "static_reports"; REPORT_DIR.mkdir(parents=True, exist_ok=True)
results = []

for p in sorted(SAMPLES_DIR.glob("**/*")):
    if not p.is_file() or p.stat().st_size < 256: 
        continue
    rec = {"path": str(p), "size": p.stat().st_size, "sha256": sha256(p)}

    # Strings sample (first ~200 lines)
    with open(p, "rb") as f:
        data = f.read()
    rec["entropy_all"] = round(entropy(data[: min(len(data), 1<<20)]), 4)  # entropy of first 1MB
    s = ascii_strings(data[: min(len(data), 1<<20)], 6)[:200]
    rec["strings_head"] = s

    # PE details
    if pefile:
        try:
            pe = pefile.PE(str(p), fast_load=True)
            pe.parse_data_directories()
            ts = getattr(pe.FILE_HEADER, "TimeDateStamp", None)
            rec["pe_timestamp_utc"] = ts
            # Sections entropy
            secs = []
            for sec in pe.sections:
                raw = sec.get_data()
                secs.append({
                    "name": sec.Name.decode(errors="ignore").strip("\x00"),
                    "raw_size": sec.SizeOfRawData,
                    "virtual_size": sec.Misc_VirtualSize,
                    "entropy": round(entropy(raw), 4) if raw else None
                })
            rec["sections"] = secs
            # Imports (top few)
            imports = []
            if hasattr(pe, "DIRECTORY_ENTRY_IMPORT"):
                for entry in pe.DIRECTORY_ENTRY_IMPORT:
                    dll = entry.dll.decode(errors="ignore") if entry.dll else ""
                    funcs = [imp.name.decode(errors="ignore") if imp.name else f"ord{imp.ordinal}" for imp in entry.imports]
                    imports.append({"dll": dll, "sample": funcs[:15]})
            rec["imports"] = imports[:5]
            # Imphash
            try:
                rec["imphash"] = pe.get_imphash()
            except Exception:
                rec["imphash"] = None
        except Exception as e:
            rec["pe_error"] = str(e)

    results.append(rec)

# Save JSON
out_json = REPORT_DIR / "static_summary.json"
out_json.write_text(json.dumps(results, indent=2), encoding="utf-8")
print("Wrote:", out_json)

# Quick IOC skim from strings
ioc_candidates = {"hosts": set(), "ips": set(), "paths": set()}
import re
ip_re = re.compile(r"\b(?:\d{1,3}\.){3}\d{1,3}\b")
url_re = re.compile(r"(?:https?://)?[A-Za-z0-9\.\-]+\.[A-Za-z]{2,}(?:/[^\s\"']*)?")
path_re = re.compile(r"[A-Za-z]:\\[^\r\n\"']+")

for rec in results:
    for s in rec.get("strings_head", []):
        for m in ip_re.findall(s): ioc_candidates["ips"].add(m)
        for m in url_re.findall(s): ioc_candidates["hosts"].add(m)
        for m in path_re.findall(s): ioc_candidates["paths"].add(m)

print("IOC candidates (head of strings):")
print({k: list(sorted(v))[:20] for k,v in ioc_candidates.items()})
# Out:
# Wrote: C:\Users\vboxuser\repos\CYBS-5014\lab3\output\static_reports\static_summary.json
# IOC candidates (head of strings):
# {'hosts': ['Inter-Medium.woff/XtF34gk4tjq8W71Z24P1Tw8HhwlPVl_Uj77uYTSOcH9IDMSSNiqNWRCUw9FZ53gtNY8esjWXNPBq3NpMXyx0uG-ZfKHFhrQTBr5MOGbVvp1-woIXEUeE82W9q_OAQ9cojvJUpDZgpasB4d6jaGX6RHheH-bePrtt6b7yVED1ZHb6pPAQZtKIIWXngnzihC6lxppsFLqUStoTvzWoNoW9gwVJT25GQYYlLrAcWrwFzs_jJAHf2', 'cmd.exe', 'mswsock.dll', 'spoolsv.exe'], 'ips': ['35.86.58.69', '8.0.422.05'], 'paths': ['C:\\Program Files', 'C:\\Program Files (x86)', 'C:\\Program Files (x86)\\Common Files', 'C:\\Program Files\\Common Files', 'C:\\Program Files\\OpenLogic\\jdk-8.0.422.05-hotspot\\bin;C:\\Windows\\system32;C:\\Windows;C:\\Windows\\System32\\Wbem;C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\;C:\\Windows\\System32\\OpenSSH\\;C:\\gradle-6.8.3\\bin;C:\\Users\\IanVeep\\AppData\\Local\\Microsoft\\WindowsApps', 'C:\\ProgramData', 'C:\\Users\\IanVeep', 'C:\\Users\\IanVeep\\AppData\\Local', 'C:\\Users\\IanVeep\\AppData\\Local\\Temp', 'C:\\Users\\IanVeep\\AppData\\Roaming', 'C:\\Users\\IanVeep\\Documents\\WindowsPowerShell\\Modules;C:\\Program Files\\WindowsPowerShell\\Modules;C:\\Windows\\system32\\WindowsPowerShell\\v1.0\\Modules', 'C:\\Users\\IanVeep\\OneDrive', 'C:\\Users\\Public', 'C:\\Windows', 'C:\\Windows\\System32\\Drivers\\DriverData', 'C:\\Windows\\System32\\spoolsv.exe', 'C:\\Windows\\system32\\cmd.exe']}

# %% [markdown]
# # Analysis
# - Artifacts analyzed (from static_summary.json):
#   - pid.14536.dmp (spoolsv.exe full memmap dump)
#     - SHA-256: a3ffb85d91af9c0eaf06f96273acf01b2bed51c0ae3e00c91ea97b1bbe345b05
#     - Entropy (first 1 MB): 2.1164 (mixed code/data; not purely packed)
#     - PE parse: not a valid PE (DOS Header magic not found.) which is expected for a raw process dump.
#
# - pid_14536_carve_0xb70000.bin (RWX page carve)
#   - SHA-256: 96e7a618d024c2e87e0c8ee4f3cd41e68f7c7b61898b44395d04e9b35334cace
#   - Entropy: 0.3861 (structured shellcode/zeroes)
#   - PE parse: not a PE - expected for a shellcode page.
#
# Clear network/C2 evidence inside pid.14536.dmp strings:
# - Direct IP C2: 35.86.58.69 (also seen in netscan).
# - HTTP over non-standard port: explicit request and response captured in strings:
#   - GET /fonts/static/Inter-Medium.woff/<long token> HTTP/1.1
#   - http://35.86.58.69:4444/fonts/static/Inter-Medium.woff/<long token>
#   - HTTP/1.1 200 OK, Transfer-Encoding: chunked, Cache-Control: no-store, no-cache, must-revalidate, Date: Mon, 17 Mar 2025 17:12:11 GMT, Content-Type: application/octet-stream. Strong indicator of HTTP C2 masquerading as font delivery on port 4444, consistent with the runtime netscan timeline.
#
# Defense/AV-evasion & LOLBAS hints (function imports/strings):
# - AmsiInitialize, AmsiScanBuffer, AmsiScanString (AMSI touchpoints).
# - WldpQueryDynamicCodeTrust, WldpIsClassInApprovedList (WDAC/Code-Integrity related).
# - winhttp, wininet, ole32/oleaut32 present in strings (network + COM usage).
# - Multiple standard environment strings (PATH, ComSpec=C:\Windows\system32\cmd.exe, USERNAME=IanVeep), AzureAD user domain, and system folders — useful for situational context, not IOCs by themselves.
#
# Noise & false positives to ignore:
# - "8.0.422.05" (caught by the IP regex) is a JDK version, not an IP.
# - "cmd.exe", "mswsock.dll", "spoolsv.exe" appeared in the “hosts” bucket due to a loose pattern - not hosts.
# - Generic Windows and user profile paths are normal context; keep only paths tied to malicious behavior.
#
# Takeaways for YARA/hunting (seed ideas):
# - Byte/ASCII markers from the carved RWX page (low entropy), use as shellcode anchors.
# - HTTP path pattern: /fonts/static/Inter-Medium.woff/ followed by a long base64-ish token.
# - Presence of AMSI/WDLP symbols combined with WinHTTP/WinINet in a process that shouldn’t be talking HTTP (spooler).

# %% [raw]
# # IOC PACK
# {
#   "network": {
#     "c2_ips": ["35.86.58.69"],
#     "c2_ports": ["80", "4444", "4443"],
#     "http_uri_patterns": [
#       "/fonts/static/Inter-Medium.woff/*"
#     ],
#     "http_response_markers": [
#       "HTTP/1.1 200 OK",
#       "Transfer-Encoding: chunked",
#       "Cache-Control: no-store, no-cache, must-revalidate",
#       "Content-Type: application/octet-stream"
#     ],
#     "notes": [
#       "4443 observed from excel-update.exe initial beacon",
#       "4444 and 80 observed from rogue spoolsv.exe",
#       "Direct-IP HTTP C2 masquerading as font delivery"
#     ]
#   },
#   "host": {
#     "suspicious_files": [
#       "C:\\Windows\\excel-update.exe"
#     ],
#     "process_chain": [
#       "PSEXESVC.exe -> excel-update.exe -> cmd.exe -> powershell.exe -> spoolsv.exe (Session 2)"
#     ],
#     "persistence_locations": [
#       "%APPDATA%\\Microsoft\\Windows\\Start Menu\\Programs\\Startup"
#     ],
#     "memory_hashes": {
#       "pid_14536_full_dump_sha256": "a3ffb85d91af9c0eaf06f96273acf01b2bed51c0ae3e00c91ea97b1bbe345b05",
#       "pid_14536_carve_0xb70000_sha256": "96e7a618d024c2e87e0c8ee4f3cd41e68f7c7b61898b44395d04e9b35334cace"
#     },
#     "behavioral_indicators": [
#       "spoolsv.exe running in Session 2 as child of PowerShell",
#       "spoolsv.exe with RWX private memory (0x0000000000B70000) and HTTP C2",
#       "AMSI and WDLP symbols present alongside WinHTTP/WinINet"
#     ]
#   },
#   "scoping_targets": [
#     "Find any hosts contacting 35.86.58.69 on 80/4443/4444",
#     "Search web proxy logs for URI pattern '/fonts/static/Inter-Medium.woff/'",
#     "Look for 'C:\\Windows\\excel-update.exe' or similarly named droppers",
#     "Enumerate Startup folder artifacts for user 'IanVeep' and peers"
#   ]
# }

# %% [markdown]
# # Summary
#
# ## Overview
# - spoolsv.exe (PID 14536) is an additional suspicious process: it runs in Session 2 as a child of interactive PowerShell, not the service tree, and contains RWX shellcode at 0x0000000000B70000.
# - From static strings in the full process dump, we see direct-IP HTTP C2 to 35.86.58.69, disguising traffic as a font download:
# `GET /fonts/static/Inter-Medium.woff/<token> HTTP/1.1` on port 4444, with `HTTP/1.1 200 OK, Transfer-Encoding: chunked`, and `Cache-Control: no-store, no-cache, must-revalidate` are fully consistent with the netscan timeline.
# - The dump also contains AMSI/WDLP symbols (e.g., AmsiScanBuffer, WldpQueryDynamicCodeTrust) and WinHTTP/WinINet markers, supporting in-process HTTP C2 and likely defense-aware behavior.
# - The process chain remains: PSEXESVC.exe -> excel-update.exe -> cmd.exe -> powershell.exe -> spoolsv.exe, with excel-update.exe earlier beaconing to 35.86.58.69:4443 and spoolsv.exe later communicating on 4444/80 — a single C2 infrastructure across stages.
#
# ## Next steps:
#
# - Contain the host; terminate the rogue spoolsv.exe and remove Startup-folder persistence.
# - Block 35.86.58.69 and hunt across the estate for HTTP requests to /fonts/static/Inter-Medium.woff/ on 80/4443/4444.
# - Scope for C:\Windows\excel-update.exe and look-alikes; review service/task creation around 17:01–17:27 UTC.
# - Use the IOC pack above (plus the shellcode page hash as a memory IOC) to drive detection, and reimage where compromise depth warrants.
